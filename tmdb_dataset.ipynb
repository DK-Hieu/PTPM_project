# %%
import requests
import pandas as pd

# %%
url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true}

# %%
url = 'https://api.themoviedb.org/3/search/movie?query=Jack+Reacher'

headers = {
             "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"     
          }

response = requests.get(url, headers=headers)
data = response.json()
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/2v3pC01rf0uXnECOM94pjfqk1TY.jpg',
#    'genre_ids': [80, 18, 53, 28],
#    'id': 75780,
#    'original_language': 'en',
#    'original_title': 'Jack Reacher',
#    'overview': "One morning in an ordinary town, five people are shot dead in a seemingly random attack. All evidence points to a single suspect: an ex-military sniper who is quickly brought into custody. The interrogation yields one written note: 'Get Jack Reacher!'. Reacher, an enigmatic ex-Army investigator, believes the authorities have the right man but agrees to help the sniper's defense attorney. However, the more Reacher delves into the case, the less clear-cut it appears. So begins an extraordinary chase for the truth, pitting Jack Reacher against an unexpected enemy, with a skill for violence and a secret to keep.",
#    'popularity': 25.104999999999997,
#    'poster_path': '/gLv55839pz4lhyKGRaJKbty41yq.jpg',
#    'release_date': '2012-12-20',
#    'title': 'Jack Reacher',
#    'video': False,
#    'vote_average': 6.639,
#    'vote_count': 7129},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 1045592,
#    'original_language': 'en',
#    'original_title': 'Jack Reacher: When the Man Comes Around',
#    'overview': "Cast and crew speak on adapting One Shot as the first Jack Reacher film, casting Tom Cruise, earning Lee Child's blessing, additional character qualities and the performances that shape them, Lee Child's cameo in the film, and shooting the film's climax.",
#    'popularity': 5.9325,
#    'poster_path': '/tcOPca5Ook6aR9mehrnxD9kfk7m.jpg',
#    'release_date': '2013-05-07',
#    'title': 'Jack Reacher: When the Man Comes Around',
#    'video': False,
#    'vote_average': 7.9,
#    'vote_count': 4},
#   {'adult': False,
#    'backdrop_path': '/ww1eIoywghjoMzRLRIcbJLuKnJH.jpg',
#    'genre_ids': [28, 53],
#    'id': 343611,
#    'original_language': 'en',
#    'original_title': 'Jack Reacher: Never Go Back',
#    'overview': 'Years after resigning command of an elite military police unit, the nomadic, righter-of-wrongs Reacher is drawn back into the life he left behind when his friend and successor, Major Susan Turner is framed for espionage. Reacher will stop at nothing to prove her innocence and to expose the real perpetrators behind the killings of his former soldiers.',
#    'popularity': 26.725,
#    'poster_path': '/cOg3UT2NYWHZxp41vpxAnVCOC4M.jpg',
#    'release_date': '2016-10-19',
#    'title': 'Jack Reacher: Never Go Back',
#    'video': False,
#    'vote_average': 5.992,
#    'vote_count': 4970}],
#  'total_pages': 1,
#  'total_results': 3}

# %%
listm = pd.read_json(r"F:\IDM_Download\Compressed\movie_ids_03_23_2025.json",lines=True)
listm
# Out:
#          adult       id                      original_title  popularity  video
# 0        False     3924                             Blondie      0.7525  False
# 1        False     6124                 Der Mann ohne Namen      0.1000  False
# 2        False     8773                 L'Amour à vingt ans      0.3475  False
# 3        False    25449  New World Disorder 9: Never Enough      0.1350  False
# 4        False    31975      Sesame Street: Elmo Loves You!      0.0500   True
# ...        ...      ...                                 ...         ...    ...
# 1038616  False  1452850                            Specimen      0.0000  False
# 1038617  False  1452851                 The private lession      0.0000  False
# 1038618  False  1452852               The World Really Is W      0.0000  False
# 1038619  False  1452853                    История её любви      0.0000  False
# 1038620  False  1452854               Ian Dury: On My Life!      0.0000  False
#
# [1038621 rows x 5 columns]

# %%
listm[listm['id']==402431]
# Out:
#         adult      id original_title  popularity  video
# 267983  False  402431         Wicked     112.525  False

# %%
url = 'https://api.themoviedb.org/3/movie/2'

headers = {
             "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"     
          }

response = requests.get(url, headers=headers)
data = response.json()
data
# Out:
# {'adult': False,
#  'backdrop_path': '/hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg',
#  'belongs_to_collection': {'id': 1382526,
#   'name': "Aki Kaurismäki's Proletariat Trilogy",
#   'poster_path': '/bUrReoZFLGti6ehkBW0xw8f12MT.jpg',
#   'backdrop_path': '/zAUItK1Nr473DIe8gWMsZ0DMR7L.jpg'},
#  'budget': 0,
#  'genres': [{'id': 35, 'name': 'Comedy'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10749, 'name': 'Romance'},
#   {'id': 80, 'name': 'Crime'}],
#  'homepage': '',
#  'id': 2,
#  'imdb_id': 'tt0094675',
#  'origin_country': ['FI'],
#  'original_language': 'fi',
#  'original_title': 'Ariel',
#  'overview': 'A Finnish man goes to the city to find a job after the mine where he worked is closed and his father commits suicide.',
#  'popularity': 1.4327,
#  'poster_path': '/ojDg0PGvs6R9xYFodRct2kdI6wC.jpg',
#  'production_companies': [{'id': 2303,
#    'logo_path': None,
#    'name': 'Villealfa Filmproductions',
#    'origin_country': 'FI'}],
#  'production_countries': [{'iso_3166_1': 'FI', 'name': 'Finland'}],
#  'release_date': '1988-10-21',
#  'revenue': 0,
#  'runtime': 73,
#  'spoken_languages': [{'english_name': 'Finnish',
#    'iso_639_1': 'fi',
#    'name': 'suomi'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': 'Ariel',
#  'video': False,
#  'vote_average': 7.111,
#  'vote_count': 346}

# %%
tmdb_id = 30
url = f'https://api.themoviedb.org/3/movie/{tmdb_id}'

headers = {
             "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"     
          }

response = requests.get(url, headers=headers)
data = response.json()
data
# Out:
# {'success': False,
#  'status_code': 34,
#  'status_message': 'The resource you requested could not be found.'}

# %%
idm = '968080'
url = f'https://api.themoviedb.org/3/movie/{idm}/reviews'

headers = {
             "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"     
          }

response = requests.get(url, headers=headers)
data = response.json()
data
# Out:
# {'success': False,
#  'status_code': 34,
#  'status_message': 'The resource you requested could not be found.'}

# %%
# images

# https://image.tmdb.org/t/p/w500/wd1PhoVfyeleAX4hMlp0FHvN284.jpg

import requests

tmdb_id = 2

url = f"https://api.themoviedb.org/3/movie/{tmdb_id}/images"

headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k" 
          }

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'backdrops': [{'aspect_ratio': 1.778,
#    'height': 900,
#    'iso_639_1': None,
#    'file_path': '/hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg',
#    'vote_average': 3.334,
#    'vote_count': 1,
#    'width': 1600},
#   {'aspect_ratio': 1.78,
#    'height': 731,
#    'iso_639_1': None,
#    'file_path': '/dQL2wJZo05GDd21VgOacMeCuyZy.jpg',
#    'vote_average': 3.334,
#    'vote_count': 1,
#    'width': 1301},
#   {'aspect_ratio': 1.778,
#    'height': 900,
#    'iso_639_1': None,
#    'file_path': '/wd1PhoVfyeleAX4hMlp0FHvN284.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1600},
#   {'aspect_ratio': 1.778,
#    'height': 900,
#    'iso_639_1': None,
#    'file_path': '/2U3LSaZtMk1HFDFhIgpx7idOVk7.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1600},
#   {'aspect_ratio': 1.778,
#    'height': 900,
#    'iso_639_1': None,
#    'file_path': '/fZ0rzH83nprexRjNn9IQBVDq5rf.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1600},
#   {'aspect_ratio': 1.778,
#    'height': 900,
#    'iso_639_1': 'nn',
#    'file_path': '/kpuTCMw3v2AuKjqGS7383uWbc8V.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1600},
#   {'aspect_ratio': 1.778,
#    'height': 900,
#    'iso_639_1': 'nn',
#    'file_path': '/e9y7AZbUXLLzs8PmeU2w4YIhn0H.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1600}],
#  'id': 2,
#  'logos': [],
#  'posters': [{'aspect_ratio': 0.667,
#    'height': 3000,
#    'iso_639_1': 'en',
#    'file_path': '/ojDg0PGvs6R9xYFodRct2kdI6wC.jpg',
#    'vote_average': 3.334,
#    'vote_count': 2,
#    'width': 2000},
#   {'aspect_ratio': 0.667,
#    'height': 3000,
#    'iso_639_1': 'fr',
#    'file_path': '/4HTJHLPLvhDG4D0m8IcUMh7i9h4.jpg',
#    'vote_average': 3.334,
#    'vote_count': 1,
#    'width': 2000},
#   {'aspect_ratio': 0.667,
#    'height': 1200,
#    'iso_639_1': 'fi',
#    'file_path': '/3Bt8Tytl9gCRxShdmup7gN8AWSg.jpg',
#    'vote_average': 3.334,
#    'vote_count': 1,
#    'width': 800},
#   {'aspect_ratio': 0.667,
#    'height': 1600,
#    'iso_639_1': 'en',
#    'file_path': '/tFw7rdKLuyBdqU0m3brJtoFEHuE.jpg',
#    'vote_average': 1.75,
#    'vote_count': 2,
#    'width': 1067},
#   {'aspect_ratio': 0.71,
#    'height': 980,
#    'iso_639_1': 'en',
#    'file_path': '/tsgSvUMHfz4Dz17iPwH9dyRVUCM.jpg',
#    'vote_average': 0.166,
#    'vote_count': 1,
#    'width': 696},
#   {'aspect_ratio': 0.667,
#    'height': 2400,
#    'iso_639_1': 'en',
#    'file_path': '/2YjINlXmReXRccONnBH4x1Q0Por.jpg',
#    'vote_average': 0.166,
#    'vote_count': 1,
#    'width': 1600},
#   {'aspect_ratio': 0.702,
#    'height': 1526,
#    'iso_639_1': 'fr',
#    'file_path': '/2PrlY8W8ZRGVKmykmgaPxkt8T8k.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1071},
#   {'aspect_ratio': 0.667,
#    'height': 2560,
#    'iso_639_1': 'ru',
#    'file_path': '/lmf5ablJDfbH7UwVhcZkbRnHK61.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1707},
#   {'aspect_ratio': 0.667,
#    'height': 750,
#    'iso_639_1': 'fi',
#    'file_path': '/zezQwt75vpXzj4Nhru0NJaCrnZO.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 500},
#   {'aspect_ratio': 0.667,
#    'height': 1099,
#    'iso_639_1': 'en',
#    'file_path': '/lSsY3Ky3BS8PF9io7LthCatBIXX.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 733},
#   {'aspect_ratio': 0.707,
#    'height': 2000,
#    'iso_639_1': 'es',
#    'file_path': '/60lW3I7dYKgZL6FrY1HvZi24prf.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1414},
#   {'aspect_ratio': 0.666,
#    'height': 1688,
#    'iso_639_1': None,
#    'file_path': '/lvSx6GdkYVu7tK4cIbgNH8ScWGu.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1125},
#   {'aspect_ratio': 0.666,
#    'height': 1643,
#    'iso_639_1': 'en',
#    'file_path': '/vAKOVrjmg1V4T1SgDok6WW6yn6E.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'width': 1095}]}

# %%
# Collection

import requests

url = "https://api.themoviedb.org/3/search/collection?query=Star%20Wars&include_adult=false&language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zZDkgOmFMVYpGAkR9Tkxw0CRnxX.jpg',
#    'id': 10,
#    'name': 'Star Wars Collection',
#    'original_language': 'en',
#    'original_name': 'Star Wars Collection',
#    'overview': 'An epic space-opera theatrical film series, which depicts the adventures of various characters "a long time ago in a galaxy far, far away…."',
#    'poster_path': '/aSrMJYmQX8kpF26LijkCsYhBMvm.jpg'},
#   {'adult': False,
#    'backdrop_path': '/zU0W0VRF0ZkN8CvjW4LGw0oSyTa.jpg',
#    'id': 302331,
#    'name': 'LEGO Star Wars Collection',
#    'original_language': 'en',
#    'original_name': 'LEGO Star Wars Collection',
#    'overview': 'A set of animated LEGO movies based on the Star Wars universe.',
#    'poster_path': '/sHlgKW5hlQvwJseJkmnkSmL3YDI.jpg'},
#   {'adult': False,
#    'backdrop_path': None,
#    'id': 141748,
#    'name': 'Robot Chicken - Star Wars Collection',
#    'original_language': 'en',
#    'original_name': 'Robot Chicken - Star Wars Collection',
#    'overview': 'A series of Robot Chicken TV films parodying the Star Wars films.',
#    'poster_path': '/m6tP4z5IIk8lIsBTpXu5H0B8hO3.jpg'},
#   {'adult': False,
#    'backdrop_path': '/cVYUqWzzUSrkLQwb4jlWAkaFCAX.jpg',
#    'id': 1004630,
#    'name': 'LEGO Star Wars (Seasonal) Collection',
#    'original_language': 'en',
#    'original_name': 'LEGO Star Wars (Seasonal) Collection',
#    'overview': 'A collection of LEGO Stars Wars seasonal specials released on Disney+.',
#    'poster_path': '/jHITUzB6fZVOYZ13YCqVTS06iyw.jpg'},
#   {'adult': False,
#    'backdrop_path': '/VXwSW7UGuNScCTy5V5H9pgioir.jpg',
#    'id': 133830,
#    'name': 'Star Wars: The Ewok Adventures Collection',
#    'original_language': 'en',
#    'original_name': 'Star Wars: The Ewok Adventures Collection',
#    'overview': "The Ewok Adventures is a 1984 American made-for-TV film duology based in the Star Wars setting. It was released theatrically in Europe as Caravan of Courage: An Ewok Adventure, and is known by that title today. The film focuses on the struggles of a brother and sister, stranded on the forest moon of Endor, in locating their parents, who have been kidnapped by a monster known as the Gorax. The film is set sometime between the fifth and sixth episodes of the Star Wars saga. It is the first of two spin-off films featuring the Ewoks from Star Wars Episode VI: Return of the Jedi. A sequel to this movie released in 1985. While the sequel's working title was simply Ewoks II, it was released as Ewoks: The Battle for Endor.",
#    'poster_path': '/vSrIbcWQJ3IL0R5DoWLh0c7HMTz.jpg'},
#   {'adult': False,
#    'backdrop_path': None,
#    'id': 423877,
#    'name': 'The Man Who Saved the World Collection',
#    'original_language': 'en',
#    'original_name': 'Dünyayı Kurtaran Adam Koleksiyonu',
#    'overview': "Dünyayı Kurtaran Adam (The Man Who Saved the World) and Dünyayi Kurtaran Adam'in Oglu (The Son of the Man who Saved the World) is a series of Turkish adventure films also known as Turkish Star Wars because of its notorious use of unauthorized footage from Star Wars and other movies worked into the film.",
#    'poster_path': '/bq8NBaPz1dbv4B1xWV7pGhXcixc.jpg'}],
#  'total_pages': 1,
#  'total_results': 10}

# %%
# Credits

import requests
import pandas as pd

tmdb_id = 227306

url = f"https://api.themoviedb.org/3/movie/{tmdb_id}/credits?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"
}

response = requests.get(url, headers=headers)

data = response.json()

df1 = pd.json_normalize(data)
data
# Out:
# {'id': 227306,
#  'cast': [{'adult': False,
#    'gender': 2,
#    'id': 85065,
#    'known_for_department': 'Acting',
#    'name': "Jack O'Connell",
#    'original_name': "Jack O'Connell",
#    'popularity': 2.5202,
#    'profile_path': '/tCzR4clrIkbkijuJBYsNoEuwRDa.jpg',
#    'cast_id': 11,
#    'character': 'Louis Zamperini',
#    'credit_id': '52fe4e9d9251416c7515c84d',
#    'order': 0},
#   {'adult': False,
#    'gender': 2,
#    'id': 558466,
#    'known_for_department': 'Acting',
#    'name': 'Alex Russell',
#    'original_name': 'Alex Russell',
#    'popularity': 0.7209,
#    'profile_path': '/6ICuiVBMCCY2phrHXpXftoKHqM2.jpg',
#    'cast_id': 17,
#    'character': 'Pete Zamperini',
#    'credit_id': '547a6f9992514150d10003bf',
#    'order': 1},
#   {'adult': False,
#    'gender': 2,
#    'id': 93210,
#    'known_for_department': 'Acting',
#    'name': 'Domhnall Gleeson',
#    'original_name': 'Domhnall Gleeson',
#    'popularity': 2.127,
#    'profile_path': '/uDbwncuKlqL0fAuucXSvgakJDrc.jpg',
#    'cast_id': 9,
#    'character': "Russel Allen 'Phil' Phillips",
#    'credit_id': '52fe4e9d9251416c7515c845',
#    'order': 2},
#   {'adult': False,
#    'gender': 2,
#    'id': 9828,
#    'known_for_department': 'Acting',
#    'name': 'Garrett Hedlund',
#    'original_name': 'Garrett Hedlund',
#    'popularity': 1.3072,
#    'profile_path': '/v5gztlEVgGJEQVp1Mf7URJJBuop.jpg',
#    'cast_id': 10,
#    'character': 'John Fitzgerald',
#    'credit_id': '52fe4e9d9251416c7515c849',
#    'order': 3},
#   {'adult': False,
#    'gender': 2,
#    'id': 1391420,
#    'known_for_department': 'Acting',
#    'name': 'MIYAVI',
#    'original_name': 'MIYAVI',
#    'popularity': 0.5243,
#    'profile_path': '/vQYBdyFdjaBmKUnYp10NgIqmxAN.jpg',
#    'cast_id': 15,
#    'character': "Mutsuhiro 'The Bird' Watanabe",
#    'credit_id': '547a6ef592514150d1000397',
#    'order': 4},
#   {'adult': False,
#    'gender': 2,
#    'id': 168877,
#    'known_for_department': 'Acting',
#    'name': 'Finn Wittrock',
#    'original_name': 'Finn Wittrock',
#    'popularity': 0.9174,
#    'profile_path': '/gwGMGTmli0uBF7eAhhXePWhYNFJ.jpg',
#    'cast_id': 12,
#    'character': "Francis 'Mac' McNamara",
#    'credit_id': '52fe4e9d9251416c7515c851',
#    'order': 5},
#   {'adult': False,
#    'gender': 2,
#    'id': 224181,
#    'known_for_department': 'Acting',
#    'name': 'Jai Courtney',
#    'original_name': 'Jai Courtney',
#    'popularity': 1.552,
#    'profile_path': '/6vEaNwbOKov6yzQx15CdtrqfK3L.jpg',
#    'cast_id': 16,
#    'character': "Hugh 'Cup' Cuppernell",
#    'credit_id': '547a6f8492514152220003e7',
#    'order': 6},
#   {'adult': False,
#    'gender': 1,
#    'id': 1394424,
#    'known_for_department': 'Acting',
#    'name': 'Maddalena Ischiale',
#    'original_name': 'Maddalena Ischiale',
#    'popularity': 0.1436,
#    'profile_path': '/xYIlplsTtmjJYgrvwUOxBYzRkpv.jpg',
#    'cast_id': 24,
#    'character': 'Louise Zamperini',
#    'credit_id': '5480861ec3a36829ae0029fd',
#    'order': 7},
#   {'adult': False,
#    'gender': 2,
#    'id': 20588,
#    'known_for_department': 'Acting',
#    'name': 'Vincenzo Amato',
#    'original_name': 'Vincenzo Amato',
#    'popularity': 0.4795,
#    'profile_path': '/6fI2F4puhODCgDVtFBLiSFtkaHL.jpg',
#    'cast_id': 28,
#    'character': 'Anthony Zamperini',
#    'credit_id': '5480866b9251416e81002c8d',
#    'order': 8},
#   {'adult': False,
#    'gender': 1,
#    'id': 1394420,
#    'known_for_department': 'Acting',
#    'name': 'Sophie Dalah',
#    'original_name': 'Sophie Dalah',
#    'popularity': 0.3466,
#    'profile_path': '/ht4CQ3zYO0EIhCFl2yMe0AzYBP5.jpg',
#    'cast_id': 20,
#    'character': 'Virginia',
#    'credit_id': '548085dac3a36829a7002cd6',
#    'order': 9},
#   {'adult': False,
#    'gender': 1,
#    'id': 98306,
#    'known_for_department': 'Acting',
#    'name': 'Morgan Griffin',
#    'original_name': 'Morgan Griffin',
#    'popularity': 0.3543,
#    'profile_path': '/kmxJBGDu7G4t2HSFRx6HK70sa7x.jpg',
#    'cast_id': 22,
#    'character': 'Cynthia Applewhite',
#    'credit_id': '548085f59251416e74002ee6',
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 1394426,
#    'known_for_department': 'Acting',
#    'name': 'Savannah Lamble',
#    'original_name': 'Savannah Lamble',
#    'popularity': 0.0214,
#    'profile_path': '/iwMaXm5pqlZhfTPoTuYncjNEoad.jpg',
#    'cast_id': 30,
#    'character': 'Sylvia Zamperini',
#    'credit_id': '5480868ec3a36817a5002b2d',
#    'order': 11},
#   {'adult': False,
#    'gender': 2,
#    'id': 103351,
#    'known_for_department': 'Acting',
#    'name': 'Luke Treadaway',
#    'original_name': 'Luke Treadaway',
#    'popularity': 0.2747,
#    'profile_path': '/kAIfKIuyucJsiMHeEAkavxTnMpi.jpg',
#    'cast_id': 19,
#    'character': 'Miller',
#    'credit_id': '548085cd9251416e7e002e29',
#    'order': 12},
#   {'adult': False,
#    'gender': 2,
#    'id': 37154,
#    'known_for_department': 'Acting',
#    'name': 'John Magaro',
#    'original_name': 'John Magaro',
#    'popularity': 1.154,
#    'profile_path': '/ah4Jm4Lmrgab9xdHwRId80S4REd.jpg',
#    'cast_id': 13,
#    'character': 'Frank A. Tinker',
#    'credit_id': '52fe4e9d9251416c7515c855',
#    'order': 13},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394446,
#    'known_for_department': 'Acting',
#    'name': 'Louis McIntosh',
#    'original_name': 'Louis McIntosh',
#    'popularity': 0.0297,
#    'profile_path': None,
#    'cast_id': 55,
#    'character': 'Lt. William Harris',
#    'credit_id': '548087d69251416e7e002e7d',
#    'order': 14},
#   {'adult': False,
#    'gender': 2,
#    'id': 1374534,
#    'known_for_department': 'Acting',
#    'name': 'Ross Anderson',
#    'original_name': 'Ross Anderson',
#    'popularity': 0.6467,
#    'profile_path': '/918MEQzDshopEdGBvotRNmp39c2.jpg',
#    'cast_id': 27,
#    'character': 'Blackie',
#    'credit_id': '54808658c3a36829a3002d24',
#    'order': 15},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394425,
#    'known_for_department': 'Acting',
#    'name': 'C.J. Valleroy',
#    'original_name': 'C.J. Valleroy',
#    'popularity': 0.0745,
#    'profile_path': '/vsuWPmCFanrTh8dXY7ruRfnYe7I.jpg',
#    'cast_id': 26,
#    'character': 'Young Louis',
#    'credit_id': '54808638c3a36829b5003599',
#    'order': 16},
#   {'adult': False,
#    'gender': 2,
#    'id': 1056523,
#    'known_for_department': 'Acting',
#    'name': "John D'Leo",
#    'original_name': "John D'Leo",
#    'popularity': 0.3145,
#    'profile_path': '/do0YtjRWmQyVvQf8S5oAMEGw0Bn.jpg',
#    'cast_id': 21,
#    'character': 'Young Pete',
#    'credit_id': '548085e8c3a36829b5003583',
#    'order': 17},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394429,
#    'known_for_department': 'Acting',
#    'name': 'Jordan Patrick Smith',
#    'original_name': 'Jordan Patrick Smith',
#    'popularity': 0.6528,
#    'profile_path': '/bGPLRUkjCHm2j8VspCOgL6mti4b.jpg',
#    'cast_id': 33,
#    'character': 'Cliff',
#    'credit_id': '548086ae9251416e78002cb1',
#    'order': 18},
#   {'adult': False,
#    'gender': 2,
#    'id': 1174927,
#    'known_for_department': 'Acting',
#    'name': 'Spencer Rocco Lofranco',
#    'original_name': 'Spencer Rocco Lofranco',
#    'popularity': 0.989,
#    'profile_path': '/fmvnLOARUpDmMZMviU2F4mH9Fmb.jpg',
#    'cast_id': 18,
#    'character': 'Harry Brooks',
#    'credit_id': '548085bf9251414d21002a1a',
#    'order': 19},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394448,
#    'known_for_department': 'Acting',
#    'name': 'Stephen J. Douglas',
#    'original_name': 'Stephen J. Douglas',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'cast_id': 59,
#    'character': 'Clarence Douglas',
#    'credit_id': '54808804c3a368299f0023b7',
#    'order': 20},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394447,
#    'known_for_department': 'Acting',
#    'name': 'Marcus Vanco',
#    'original_name': 'Marcus Vanco',
#    'popularity': 0.1538,
#    'profile_path': '/iIlR0KBVjBgy03e0bVj0WpKuMgw.jpg',
#    'cast_id': 57,
#    'character': 'Lambert',
#    'credit_id': '548087eec3a36829ae002a3c',
#    'order': 21},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394431,
#    'known_for_department': 'Acting',
#    'name': 'Dylan James Watson',
#    'original_name': 'Dylan James Watson',
#    'popularity': 0.094,
#    'profile_path': '/3esAs7UjyHOkUWRcqbO79Wdzgft.jpg',
#    'cast_id': 37,
#    'character': 'Green Hornet Engineer',
#    'credit_id': '548086e0c3a36829b50035be',
#    'order': 22},
#   {'adult': False,
#    'gender': 2,
#    'id': 970534,
#    'known_for_department': 'Acting',
#    'name': 'Ryan Ahern',
#    'original_name': 'Ryan Ahern',
#    'popularity': 0.2793,
#    'profile_path': '/3ggSi62hsL42iBSlUyLHsDr6F8K.jpg',
#    'cast_id': 50,
#    'character': 'Glassman',
#    'credit_id': '5480877ec3a36817a5002b5a',
#    'order': 23},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394444,
#    'known_for_department': 'Acting',
#    'name': 'Ross Langley',
#    'original_name': 'Ross Langley',
#    'popularity': 0.0261,
#    'profile_path': None,
#    'cast_id': 54,
#    'character': 'Mitchell',
#    'credit_id': '548087c6c3a368299f0023ac',
#    'order': 24},
#   {'adult': False,
#    'gender': 2,
#    'id': 212730,
#    'known_for_department': 'Acting',
#    'name': 'Michael Whalley',
#    'original_name': 'Michael Whalley',
#    'popularity': 0.1277,
#    'profile_path': '/56Ci67VeXGD0To4z99bK96Z7Edg.jpg',
#    'cast_id': 44,
#    'character': 'Stanley Pillsbury',
#    'credit_id': '548087339251414d21002a62',
#    'order': 25},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394423,
#    'known_for_department': 'Acting',
#    'name': "Sean O'Donnell",
#    'original_name': "Sean O'Donnell",
#    'popularity': 0.1901,
#    'profile_path': '/bfM7p3iEnfpX08KKChY2fWthGkn.jpg',
#    'cast_id': 23,
#    'character': 'Boy(s) (voice)',
#    'credit_id': '54808610c3a36829ab002d83',
#    'order': 26},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394427,
#    'known_for_department': 'Acting',
#    'name': 'Travis Jeffery',
#    'original_name': 'Travis Jeffery',
#    'popularity': 0.4261,
#    'profile_path': '/picKz6F5ZNpZeDF1oRXHpSR8V8w.jpg',
#    'cast_id': 31,
#    'character': 'Jimmy',
#    'credit_id': '54808699c3a36829a7002cf5',
#    'order': 27},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394428,
#    'known_for_department': 'Acting',
#    'name': 'James McEnery',
#    'original_name': 'James McEnery',
#    'popularity': 0.0453,
#    'profile_path': None,
#    'cast_id': 32,
#    'character': 'Marine at Airbase',
#    'credit_id': '548086a49251416e6c00292f',
#    'order': 28},
#   {'adult': False,
#    'gender': 2,
#    'id': 1213640,
#    'known_for_department': 'Acting',
#    'name': 'Stephen Stanton',
#    'original_name': 'Stephen Stanton',
#    'popularity': 0.6012,
#    'profile_path': '/uaoZXILATHT27HUnBh8Q345glc6.jpg',
#    'cast_id': 34,
#    'character': 'Berlin Olympics Radio Announcer (voice)',
#    'credit_id': '548086bc9251416e78002cb6',
#    'order': 29},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394430,
#    'known_for_department': 'Acting',
#    'name': 'Talia Mano',
#    'original_name': 'Talia Mano',
#    'popularity': 0.0071,
#    'profile_path': None,
#    'cast_id': 35,
#    'character': 'Young Sylvia',
#    'credit_id': '548086c69251414efa002e1f',
#    'order': 30},
#   {'adult': False,
#    'gender': 2,
#    'id': 75748,
#    'known_for_department': 'Acting',
#    'name': 'Yutaka Izumihara',
#    'original_name': 'Yutaka Izumihara',
#    'popularity': 0.1023,
#    'profile_path': '/bWTOjEMApMOR475fyg2P2fbNTlA.jpg',
#    'cast_id': 36,
#    'character': 'Radio Tokyo Man',
#    'credit_id': '548086d19251416e78002cbd',
#    'order': 31},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394432,
#    'known_for_department': 'Acting',
#    'name': 'Hisa Goto',
#    'original_name': 'Hisa Goto',
#    'popularity': 0.0409,
#    'profile_path': None,
#    'cast_id': 38,
#    'character': 'Omori guard',
#    'credit_id': '548086ebc3a36829ab002da4',
#    'order': 32},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394433,
#    'known_for_department': 'Acting',
#    'name': 'Hiroshi Kasuga',
#    'original_name': 'Hiroshi Kasuga',
#    'popularity': 0.1481,
#    'profile_path': '/lKi2oPCGSeotF4WidIyYztyM8Qp.jpg',
#    'cast_id': 39,
#    'character': 'Naoetsu Guard 1',
#    'credit_id': '548086f6c3a36829a7002d05',
#    'order': 33},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394434,
#    'known_for_department': 'Acting',
#    'name': 'Akira Fujii',
#    'original_name': 'Akira Fujii',
#    'popularity': 0.0478,
#    'profile_path': None,
#    'cast_id': 40,
#    'character': 'Japanese Athlete',
#    'credit_id': '548087059251414d21002a55',
#    'order': 34},
#   {'adult': False,
#    'gender': 0,
#    'id': 1110812,
#    'known_for_department': 'Acting',
#    'name': 'Chris Proctor',
#    'original_name': 'Chris Proctor',
#    'popularity': 0.0379,
#    'profile_path': None,
#    'cast_id': 41,
#    'character': 'James',
#    'credit_id': '548087119251416e7e002e5a',
#    'order': 35},
#   {'adult': False,
#    'gender': 0,
#    'id': 1205489,
#    'known_for_department': 'Acting',
#    'name': 'Shinji Ikefuji',
#    'original_name': 'Shinji Ikefuji',
#    'popularity': 0.1393,
#    'profile_path': None,
#    'cast_id': 42,
#    'character': 'Japanese Translator',
#    'credit_id': '5480871d9251416e7e002e5c',
#    'order': 36},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394435,
#    'known_for_department': 'Acting',
#    'name': 'Brodie Henson',
#    'original_name': 'Brodie Henson',
#    'popularity': 0.0495,
#    'profile_path': None,
#    'cast_id': 43,
#    'character': 'British p.o.w',
#    'credit_id': '54808728c3a36829ab002db0',
#    'order': 37},
#   {'adult': False,
#    'gender': 2,
#    'id': 1059787,
#    'known_for_department': 'Acting',
#    'name': 'Shingo Usami',
#    'original_name': 'Shingo Usami',
#    'popularity': 0.1089,
#    'profile_path': '/oFG4YSArNyicK0q9UISfhnokmhG.jpg',
#    'cast_id': 45,
#    'character': 'Corporal Kono',
#    'credit_id': '5480873ec3a36817a5002b4d',
#    'order': 38},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394437,
#    'known_for_department': 'Acting',
#    'name': 'Stefan Mogel',
#    'original_name': 'Stefan Mogel',
#    'popularity': 0.0361,
#    'profile_path': None,
#    'cast_id': 46,
#    'character': 'SS Guard',
#    'credit_id': '54808749c3a36829a3002d46',
#    'order': 39},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394438,
#    'known_for_department': 'Acting',
#    'name': 'Clay Zamperini',
#    'original_name': 'Clay Zamperini',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'cast_id': 47,
#    'character': 'Torch Bearer',
#    'credit_id': '548087549251414d21002a6e',
#    'order': 40},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394439,
#    'known_for_department': 'Acting',
#    'name': 'Jess Terrell',
#    'original_name': 'Jess Terrell',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'cast_id': 48,
#    'character': 'American POW',
#    'credit_id': '54808764c3a36829a3002d4d',
#    'order': 41},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394440,
#    'known_for_department': 'Acting',
#    'name': 'Sean-Ryan Petersen',
#    'original_name': 'Sean-Ryan Petersen',
#    'popularity': 0.1427,
#    'profile_path': '/hmwgdQmouzJ6benqEvvsEkqnDWY.jpg',
#    'cast_id': 49,
#    'character': 'Boy',
#    'credit_id': '548087719251416e81002cc1',
#    'order': 42},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394442,
#    'known_for_department': 'Acting',
#    'name': 'Toby Fuller',
#    'original_name': 'Toby Fuller',
#    'popularity': 0.1068,
#    'profile_path': None,
#    'cast_id': 51,
#    'character': 'Spike Runner',
#    'credit_id': '54808796c3a36829ab002dc4',
#    'order': 43},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394443,
#    'known_for_department': 'Acting',
#    'name': 'Conor Fogarty',
#    'original_name': 'Conor Fogarty',
#    'popularity': 0.0717,
#    'profile_path': '/qziswXI88fWRzRodru7ZIeYvTPd.jpg',
#    'cast_id': 52,
#    'character': 'American POW',
#    'credit_id': '548087ab9251416e78002cdd',
#    'order': 44},
#   {'adult': False,
#    'gender': 2,
#    'id': 117020,
#    'known_for_department': 'Sound',
#    'name': 'Jack Marshall',
#    'original_name': 'Jack Marshall',
#    'popularity': 0.1062,
#    'profile_path': None,
#    'cast_id': 53,
#    'character': 'Bully',
#    'credit_id': '548087b7c3a36829a7002d1f',
#    'order': 45},
#   {'adult': False,
#    'gender': 2,
#    'id': 1179405,
#    'known_for_department': 'Acting',
#    'name': 'Taki Abe',
#    'original_name': 'Taki Abe',
#    'popularity': 0.1597,
#    'profile_path': '/3dliIqdx9nxOAm3xGDH5eJrwpRp.jpg',
#    'cast_id': 56,
#    'character': 'Radio Tokyo Man',
#    'credit_id': '548087e1c3a36817a5002b6c',
#    'order': 46},
#   {'adult': False,
#    'gender': 2,
#    'id': 1381319,
#    'known_for_department': 'Acting',
#    'name': 'Keiichi Enomoto',
#    'original_name': 'Keiichi Enomoto',
#    'popularity': 0.0796,
#    'profile_path': '/kE70xPNMCiLMN5E3oggnuzUkFaz.jpg',
#    'cast_id': 58,
#    'character': 'Omori Guard',
#    'credit_id': '548087f99251416e81002cd9',
#    'order': 47},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394450,
#    'known_for_department': 'Acting',
#    'name': 'Taka Uematsu',
#    'original_name': 'Taka Uematsu',
#    'popularity': 0.0693,
#    'profile_path': '/gGm0HqTuBTg6o1CXzz9jcwPA25w.jpg',
#    'cast_id': 60,
#    'character': 'Kwajalein Guard',
#    'credit_id': '548088109251416e81002cde',
#    'order': 48},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394451,
#    'known_for_department': 'Acting',
#    'name': 'Yoji Tatsuta',
#    'original_name': 'Yoji Tatsuta',
#    'popularity': 0.1366,
#    'profile_path': '/1Tgv8eNIlbhufnTgiDzk6uV5i9k.jpg',
#    'cast_id': 61,
#    'character': 'Naoetsu Guard 2',
#    'credit_id': '5480881d9251416e7e002e8a',
#    'order': 49},
#   {'adult': False,
#    'gender': 2,
#    'id': 1361564,
#    'known_for_department': 'Acting',
#    'name': 'John Michael Burdon',
#    'original_name': 'John Michael Burdon',
#    'popularity': 0.0352,
#    'profile_path': '/dxi4e94qxikKqhD79Mml6WpH1Tz.jpg',
#    'cast_id': 62,
#    'character': 'Man in Stadium',
#    'credit_id': '54808829c3a36829b50035f5',
#    'order': 50},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394452,
#    'known_for_department': 'Acting',
#    'name': 'Ben Rossberg',
#    'original_name': 'Ben Rossberg',
#    'popularity': 0.0261,
#    'profile_path': None,
#    'cast_id': 63,
#    'character': 'British POW Officer',
#    'credit_id': '54808834c3a36829ab002dda',
#    'order': 51},
#   {'adult': False,
#    'gender': 2,
#    'id': 1328711,
#    'known_for_department': 'Acting',
#    'name': 'Sean Edward Frazer',
#    'original_name': 'Sean Edward Frazer',
#    'popularity': 0.1034,
#    'profile_path': '/lxWQWwuPt4wePrSBg1nD3NT9sb4.jpg',
#    'cast_id': 64,
#    'character': 'US Officer p.o.w',
#    'credit_id': '5480883fc3a36817a5002b74',
#    'order': 52},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394454,
#    'known_for_department': 'Crew',
#    'name': 'Yoshinao Aonuma',
#    'original_name': 'Yoshinao Aonuma',
#    'popularity': 0.1047,
#    'profile_path': None,
#    'cast_id': 65,
#    'character': 'Kwajalein Guard',
#    'credit_id': '5480884ac3a36829ab002de2',
#    'order': 53},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394455,
#    'known_for_department': 'Acting',
#    'name': 'James Storer',
#    'original_name': 'James Storer',
#    'popularity': 0.0554,
#    'profile_path': None,
#    'cast_id': 66,
#    'character': 'American P.O.W.',
#    'credit_id': '54808855c3a368299f0023c4',
#    'order': 54},
#   {'adult': True,
#    'gender': 0,
#    'id': 1394456,
#    'known_for_department': 'Acting',
#    'name': 'Joel Knights',
#    'original_name': 'Joel Knights',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 67,
#    'character': 'British POW Officer',
#    'credit_id': '548088619251416e6c002973',
#    'order': 55},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394457,
#    'known_for_department': 'Acting',
#    'name': 'Kristopher Bos',
#    'original_name': 'Kristopher Bos',
#    'popularity': 0.0143,
#    'profile_path': None,
#    'cast_id': 68,
#    'character': 'U.S. Officer P.O.W.',
#    'credit_id': '54808876c3a36829b20035c7',
#    'order': 56},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394458,
#    'known_for_department': 'Acting',
#    'name': 'Katsu Nojiri',
#    'original_name': 'Katsu Nojiri',
#    'popularity': 0.0453,
#    'profile_path': None,
#    'cast_id': 69,
#    'character': 'Omori Guard',
#    'credit_id': '548088879251416e81002cf0',
#    'order': 57},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394459,
#    'known_for_department': 'Acting',
#    'name': 'Matt Hurley',
#    'original_name': 'Matt Hurley',
#    'popularity': 0.0327,
#    'profile_path': None,
#    'cast_id': 70,
#    'character': 'US Officer P.O.W',
#    'credit_id': '54808895c3a36829ae002a5d',
#    'order': 58},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394460,
#    'known_for_department': 'Acting',
#    'name': 'Shane Leckenby',
#    'original_name': 'Shane Leckenby',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'cast_id': 71,
#    'character': 'British POW',
#    'credit_id': '548088a09251416e6c002983',
#    'order': 59},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394461,
#    'known_for_department': 'Acting',
#    'name': 'Connor Clarke',
#    'original_name': 'Connor Clarke',
#    'popularity': 0.1486,
#    'profile_path': None,
#    'cast_id': 72,
#    'character': 'American P.O.W',
#    'credit_id': '548088ab9251416e7e002ea1',
#    'order': 60},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394462,
#    'known_for_department': 'Acting',
#    'name': 'Steven Carnuccio',
#    'original_name': 'Steven Carnuccio',
#    'popularity': 0.0143,
#    'profile_path': None,
#    'cast_id': 73,
#    'character': 'Church Attendee',
#    'credit_id': '548088b69251416e74002f62',
#    'order': 61},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394463,
#    'known_for_department': 'Acting',
#    'name': 'Matthew Crocker',
#    'original_name': 'Matthew Crocker',
#    'popularity': 0.0143,
#    'profile_path': None,
#    'cast_id': 74,
#    'character': 'Australian P.O.W',
#    'credit_id': '548088c0c3a36829a7002d3a',
#    'order': 62},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394464,
#    'known_for_department': 'Acting',
#    'name': 'Connor Zegenhagen',
#    'original_name': 'Connor Zegenhagen',
#    'popularity': 0.0389,
#    'profile_path': '/wF18HGoPyH7qSb22pAuJTsYFLWB.jpg',
#    'cast_id': 75,
#    'character': 'British Soldier',
#    'credit_id': '548088cac3a36829ab002dfa',
#    'order': 63},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394465,
#    'known_for_department': 'Acting',
#    'name': 'Nicholas Farris',
#    'original_name': 'Nicholas Farris',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'cast_id': 76,
#    'character': 'Olympic Race Starter',
#    'credit_id': '548088d69251416e74002f6c',
#    'order': 64},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394466,
#    'known_for_department': 'Acting',
#    'name': 'Sarah Alison',
#    'original_name': 'Sarah Alison',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'cast_id': 77,
#    'character': 'Virginia',
#    'credit_id': '548088e1c3a36829a7002d46',
#    'order': 65},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394467,
#    'known_for_department': 'Acting',
#    'name': 'Mathew Hislop',
#    'original_name': 'Mathew Hislop',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'cast_id': 78,
#    'character': 'Australian POW',
#    'credit_id': '548088ec9251416e7b002ac8',
#    'order': 66},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394468,
#    'known_for_department': 'Acting',
#    'name': 'Matthew McConnell',
#    'original_name': 'Matthew McConnell',
#    'popularity': 0.0239,
#    'profile_path': None,
#    'cast_id': 79,
#    'character': 'American P.O.W',
#    'credit_id': '548088fac3a36817a5002b91',
#    'order': 67},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394469,
#    'known_for_department': 'Acting',
#    'name': 'Dougal Walker',
#    'original_name': 'Dougal Walker',
#    'popularity': 0.0239,
#    'profile_path': None,
#    'cast_id': 80,
#    'character': 'British POW',
#    'credit_id': '548089049251416e7b002acf',
#    'order': 68},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394470,
#    'known_for_department': 'Acting',
#    'name': 'Jack Alcock',
#    'original_name': 'Jack Alcock',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'cast_id': 81,
#    'character': 'American POW',
#    'credit_id': '5480890e9251416e6c002990',
#    'order': 69},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394471,
#    'known_for_department': 'Acting',
#    'name': 'Darren Wyer',
#    'original_name': 'Darren Wyer',
#    'popularity': 0.0143,
#    'profile_path': None,
#    'cast_id': 82,
#    'character': 'Infirmary p.o.w',
#    'credit_id': '5480891b9251416e6c00299a',
#    'order': 70},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394472,
#    'known_for_department': 'Acting',
#    'name': 'Andy de Lore',
#    'original_name': 'Andy de Lore',
#    'popularity': 0.0327,
#    'profile_path': None,
#    'cast_id': 83,
#    'character': 'Infirmary POW',
#    'credit_id': '5480892fc3a36829a3002d84',
#    'order': 71},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394473,
#    'known_for_department': 'Acting',
#    'name': 'Mitch Christen',
#    'original_name': 'Mitch Christen',
#    'popularity': 0.0286,
#    'profile_path': None,
#    'cast_id': 84,
#    'character': 'British POW (uncredited)',
#    'credit_id': '5480893c9251416e81002d14',
#    'order': 72},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394474,
#    'known_for_department': 'Acting',
#    'name': 'Matt Clayton',
#    'original_name': 'Matt Clayton',
#    'popularity': 0.0264,
#    'profile_path': None,
#    'cast_id': 85,
#    'character': 'US Enlisted POW (uncredited)',
#    'credit_id': '5480895fc3a36829b5003628',
#    'order': 73},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394476,
#    'known_for_department': 'Acting',
#    'name': 'Darren Gallagher',
#    'original_name': 'Darren Gallagher',
#    'popularity': 0.0256,
#    'profile_path': None,
#    'cast_id': 87,
#    'character': 'Soldier (uncredited)',
#    'credit_id': '548089769251416e81002d23',
#    'order': 74},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394477,
#    'known_for_department': 'Acting',
#    'name': 'Kent Lee',
#    'original_name': 'Kent Lee',
#    'popularity': 0.0322,
#    'profile_path': '/1nthCWyw31OpPxNiTSiwX7XnrGQ.jpg',
#    'cast_id': 88,
#    'character': 'Olympic spectator / Japanese Olympic team member (uncredited)',
#    'credit_id': '54808983c3a368299f0023f8',
#    'order': 75},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394478,
#    'known_for_department': 'Acting',
#    'name': 'Beau Paley',
#    'original_name': 'Beau Paley',
#    'popularity': 0.0362,
#    'profile_path': None,
#    'cast_id': 89,
#    'character': 'American POW (uncredited)',
#    'credit_id': '5480898fc3a36829ae002a79',
#    'order': 76},
#   {'adult': False,
#    'gender': 2,
#    'id': 1194035,
#    'known_for_department': 'Acting',
#    'name': 'Craig Walker',
#    'original_name': 'Craig Walker',
#    'popularity': 0.0897,
#    'profile_path': '/hHvt5Hd4rBoEdxeHb07IjdmH2Wd.jpg',
#    'cast_id': 90,
#    'character': 'Berlin Olympics Spectator (uncredited)',
#    'credit_id': '548089d3c3a36829ab002e20',
#    'order': 77}],
#  'crew': [{'adult': False,
#    'gender': 1,
#    'id': 11701,
#    'known_for_department': 'Acting',
#    'name': 'Angelina Jolie',
#    'original_name': 'Angelina Jolie',
#    'popularity': 10.9892,
#    'profile_path': '/bXNxIKcJ5cNNW8QFrBPWcfTSu9x.jpg',
#    'credit_id': '52fe4e9d9251416c7515c817',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1224,
#    'known_for_department': 'Directing',
#    'name': 'Ethan Coen',
#    'original_name': 'Ethan Coen',
#    'popularity': 0.829,
#    'profile_path': '/ccvoiEe3gEMAth1Oy8SJxVeMcAk.jpg',
#    'credit_id': '52fe4e9d9251416c7515c81d',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1223,
#    'known_for_department': 'Directing',
#    'name': 'Joel Coen',
#    'original_name': 'Joel Coen',
#    'popularity': 0.6932,
#    'profile_path': '/rgVaJNkZCgMarUcZuUAsVfXMWk3.jpg',
#    'credit_id': '52fe4e9d9251416c7515c823',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2163,
#    'known_for_department': 'Writing',
#    'name': 'Richard LaGravenese',
#    'original_name': 'Richard LaGravenese',
#    'popularity': 0.9239,
#    'profile_path': '/vCXgeY2gJXSSGTm9cy71268wGx5.jpg',
#    'credit_id': '52fe4e9d9251416c7515c829',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1143709,
#    'known_for_department': 'Writing',
#    'name': 'Matthew Barr',
#    'original_name': 'Matthew Barr',
#    'popularity': 0.0468,
#    'profile_path': None,
#    'credit_id': '52fe4e9d9251416c7515c82f',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 11701,
#    'known_for_department': 'Acting',
#    'name': 'Angelina Jolie',
#    'original_name': 'Angelina Jolie',
#    'popularity': 10.9892,
#    'profile_path': '/bXNxIKcJ5cNNW8QFrBPWcfTSu9x.jpg',
#    'credit_id': '52fe4e9d9251416c7515c835',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 10950,
#    'known_for_department': 'Production',
#    'name': 'Erwin Stoff',
#    'original_name': 'Erwin Stoff',
#    'popularity': 0.0875,
#    'profile_path': None,
#    'credit_id': '52fe4e9d9251416c7515c83b',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 3184,
#    'known_for_department': 'Production',
#    'name': 'Clayton Townsend',
#    'original_name': 'Clayton Townsend',
#    'popularity': 0.2535,
#    'profile_path': '/xN3iGckpelbvAXdCIkaOEIWcmCZ.jpg',
#    'credit_id': '52fe4e9d9251416c7515c841',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 151,
#    'known_for_department': 'Camera',
#    'name': 'Roger Deakins',
#    'original_name': 'Roger Deakins',
#    'popularity': 0.4902,
#    'profile_path': '/pSCN7CfILlfQrxX43Kgqrx5mBYQ.jpg',
#    'credit_id': '531b62dd92514177b1004164',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1459743,
#    'known_for_department': 'Visual Effects',
#    'name': 'Erik Baker',
#    'original_name': 'Erik Baker',
#    'popularity': 0.0908,
#    'profile_path': None,
#    'credit_id': '55404b749251414aee000a8c',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 15841,
#    'known_for_department': 'Editing',
#    'name': 'William Goldenberg',
#    'original_name': 'William Goldenberg',
#    'popularity': 0.1505,
#    'profile_path': '/eOgoea8HbZt2TfLn0tDNI1TepSN.jpg',
#    'credit_id': '554ddc9ac3a3685e4c0073a5',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1635,
#    'known_for_department': 'Editing',
#    'name': 'Tim Squyres',
#    'original_name': 'Tim Squyres',
#    'popularity': 0.0889,
#    'profile_path': '/5vin1Qr62tCtY7XjdDF8WJd9PzF.jpg',
#    'credit_id': '554ddcabc3a3682594003cc7',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 6410,
#    'known_for_department': 'Production',
#    'name': 'Francine Maisler',
#    'original_name': 'Francine Maisler',
#    'popularity': 0.4248,
#    'profile_path': '/5pOiu0SLr3XCB3a8SDwQ70KHINq.jpg',
#    'credit_id': '554ddcbf9251416984001309',
#    'department': 'Production',
#    'job': 'Casting'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2243,
#    'known_for_department': 'Art',
#    'name': 'Jon Hutman',
#    'original_name': 'Jon Hutman',
#    'popularity': 0.147,
#    'profile_path': '/wbML5hLhKKXqqbUhWPbjhEhVV95.jpg',
#    'credit_id': '554ddcdac3a3681950001498',
#    'department': 'Art',
#    'job': 'Production Design'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1391707,
#    'known_for_department': 'Art',
#    'name': 'Bill Booth',
#    'original_name': 'Bill Booth',
#    'popularity': 0.0721,
#    'profile_path': None,
#    'credit_id': '554ddcf0c3a3685e50006967',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1391711,
#    'known_for_department': 'Art',
#    'name': 'Jacinta Leong',
#    'original_name': 'Jacinta Leong',
#    'popularity': 0.2148,
#    'profile_path': None,
#    'credit_id': '554ddd099251413e40001e57',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 1,
#    'id': 61485,
#    'known_for_department': 'Art',
#    'name': 'Lisa Thompson',
#    'original_name': 'Lisa Thompson',
#    'popularity': 0.2955,
#    'profile_path': None,
#    'credit_id': '554ddd679251413fcf003c72',
#    'department': 'Art',
#    'job': 'Set Decoration'},
#   {'adult': False,
#    'gender': 1,
#    'id': 4061,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Louise Frogley',
#    'original_name': 'Louise Frogley',
#    'popularity': 0.2678,
#    'profile_path': None,
#    'credit_id': '554ddd7cc3a36824310045bb',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Design'},
#   {'adult': False,
#    'gender': 2,
#    'id': 52165,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Rick Findlater',
#    'original_name': 'Rick Findlater',
#    'popularity': 0.1908,
#    'profile_path': '/iUOfvoZIY8pZhMWdkj2hVwAnQ0C.jpg',
#    'credit_id': '554dddaec3a3681a3b001eb3',
#    'department': 'Costume & Make-Up',
#    'job': 'Hairstylist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 75143,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Nik Dorning',
#    'original_name': 'Nik Dorning',
#    'popularity': 0.0897,
#    'profile_path': None,
#    'credit_id': '554ddde29251416984001344',
#    'department': 'Costume & Make-Up',
#    'job': 'Makeup Artist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1465351,
#    'known_for_department': 'Art',
#    'name': 'John Higgins',
#    'original_name': 'John Higgins',
#    'popularity': 0.1148,
#    'profile_path': None,
#    'credit_id': '554dde349251410afb001978',
#    'department': 'Art',
#    'job': 'Art Department Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1355535,
#    'known_for_department': 'Art',
#    'name': 'Jocelyn Thomas',
#    'original_name': 'Jocelyn Thomas',
#    'popularity': 0.069,
#    'profile_path': None,
#    'credit_id': '554dde4ac3a3685e5000699e',
#    'department': 'Art',
#    'job': 'Art Department Coordinator'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1330048,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'John Casey',
#    'original_name': 'John Casey',
#    'popularity': 0.1021,
#    'profile_path': None,
#    'credit_id': '554dde869251410afb00198f',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1465352,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Elly Kamal',
#    'original_name': 'Elly Kamal',
#    'popularity': 0.0871,
#    'profile_path': None,
#    'credit_id': '554ddea3c3a3681a3b001ed2',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1425397,
#    'known_for_department': 'Directing',
#    'name': 'Kristin Witcombe',
#    'original_name': 'Kristin Witcombe',
#    'popularity': 0.0659,
#    'profile_path': None,
#    'credit_id': '554ddee7925141402a003f28',
#    'department': 'Directing',
#    'job': 'Script Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 933,
#    'known_for_department': 'Writing',
#    'name': 'William Nicholson',
#    'original_name': 'William Nicholson',
#    'popularity': 0.628,
#    'profile_path': '/szH7cvOglYQn2pOeuorbQOtoiAO.jpg',
#    'credit_id': '55f76306c3a3686d0b00c3b3',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 2,
#    'id': 9583,
#    'known_for_department': 'Art',
#    'name': 'Charlie Revai',
#    'original_name': 'Charlie Revai',
#    'popularity': 0.1908,
#    'profile_path': None,
#    'credit_id': '570bd9a2c3a36802a300046c',
#    'department': 'Art',
#    'job': 'Supervising Art Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 61824,
#    'known_for_department': 'Directing',
#    'name': 'Mick Garris',
#    'original_name': 'Mick Garris',
#    'popularity': 0.4145,
#    'profile_path': '/mZUsXhL7H5DgaQL98qslFrgp1yl.jpg',
#    'credit_id': '65bce7f92b8a43017b1ddbeb',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2949,
#    'known_for_department': 'Sound',
#    'name': 'Alexandre Desplat',
#    'original_name': 'Alexandre Desplat',
#    'popularity': 0.3941,
#    'profile_path': '/tcSzPODyAu9kvLIEossR0laMgUu.jpg',
#    'credit_id': '66102620497560017d4ecc4c',
#    'department': 'Sound',
#    'job': 'Original Music Composer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 9583,
#    'known_for_department': 'Art',
#    'name': 'Charlie Revai',
#    'original_name': 'Charlie Revai',
#    'popularity': 0.1908,
#    'profile_path': None,
#    'credit_id': '598a1c51c3a36874f201ceb2',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1069714,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Toni G',
#    'original_name': 'Toni G',
#    'popularity': 0.0696,
#    'profile_path': None,
#    'credit_id': '598a1cb79251414bb401beb7',
#    'department': 'Costume & Make-Up',
#    'job': 'Makeup Department Head'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1866242,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Karen Kelly',
#    'original_name': 'Karen Kelly',
#    'popularity': 0.0646,
#    'profile_path': None,
#    'credit_id': '598a1d169251414bd101adf5',
#    'department': 'Costume & Make-Up',
#    'job': 'Hairstylist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866245,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Belinda Nicoll',
#    'original_name': 'Belinda Nicoll',
#    'popularity': 0.0281,
#    'profile_path': None,
#    'credit_id': '598a1d57c3a368755f01d17b',
#    'department': 'Costume & Make-Up',
#    'job': 'Makeup Artist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1401639,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Jennifer Stanfield',
#    'original_name': 'Jennifer Stanfield',
#    'popularity': 0.1346,
#    'profile_path': None,
#    'credit_id': '598a1d9ac3a36824a000d606',
#    'department': 'Costume & Make-Up',
#    'job': 'Hairstylist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1578022,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Shane Thomas',
#    'original_name': 'Shane Thomas',
#    'popularity': 0.1103,
#    'profile_path': None,
#    'credit_id': '598a1e0ac3a3687865017683',
#    'department': 'Costume & Make-Up',
#    'job': 'Makeup Artist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 7531,
#    'known_for_department': 'Directing',
#    'name': 'Joseph P. Reidy',
#    'original_name': 'Joseph P. Reidy',
#    'popularity': 0.3222,
#    'profile_path': '/bJ8UYZeu9kKVj2MIP1sfPt0kGWZ.jpg',
#    'credit_id': '598a1e56925141329e016736',
#    'department': 'Directing',
#    'job': 'First Assistant Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1412735,
#    'known_for_department': 'Art',
#    'name': 'Bob Booker',
#    'original_name': 'Bob Booker',
#    'popularity': 0.0722,
#    'profile_path': None,
#    'credit_id': '598a1ea1c3a3687865017730',
#    'department': 'Art',
#    'job': 'Construction Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1536898,
#    'known_for_department': 'Crew',
#    'name': 'John Bowring',
#    'original_name': 'John Bowring',
#    'popularity': 0.0352,
#    'profile_path': None,
#    'credit_id': '598a1ed9925141329e0167bc',
#    'department': 'Crew',
#    'job': 'Armorer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1536893,
#    'known_for_department': 'Art',
#    'name': 'Bernie Childs',
#    'original_name': 'Bernie Childs',
#    'popularity': 0.0566,
#    'profile_path': None,
#    'credit_id': '598a1f10c3a36824e200dc56',
#    'department': 'Art',
#    'job': 'Construction Coordinator'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1425376,
#    'known_for_department': 'Art',
#    'name': 'Nicholas Dare',
#    'original_name': 'Nicholas Dare',
#    'popularity': 0.1443,
#    'profile_path': None,
#    'credit_id': '598a1f7e9251414bd101b081',
#    'department': 'Art',
#    'job': 'Set Designer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866259,
#    'known_for_department': 'Art',
#    'name': 'Mark Diggins',
#    'original_name': 'Mark Diggins',
#    'popularity': 0.0286,
#    'profile_path': None,
#    'credit_id': '598a1fb5c3a36874ff019a52',
#    'department': 'Art',
#    'job': 'Construction Foreman'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866260,
#    'known_for_department': 'Visual Effects',
#    'name': 'Nic Gribben',
#    'original_name': 'Nic Gribben',
#    'popularity': 0.0071,
#    'profile_path': None,
#    'credit_id': '598a1ff59251414bd101b0f7',
#    'department': 'Visual Effects',
#    'job': 'Modeling'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1816360,
#    'known_for_department': 'Art',
#    'name': 'Andrew Kattie',
#    'original_name': 'Andrew Kattie',
#    'popularity': 0.0764,
#    'profile_path': None,
#    'credit_id': '598a20639251416b50019a48',
#    'department': 'Art',
#    'job': 'Set Designer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1730964,
#    'known_for_department': 'Crew',
#    'name': 'Allan Mowbray',
#    'original_name': 'Allan Mowbray',
#    'popularity': 0.0331,
#    'profile_path': None,
#    'credit_id': '598a2098c3a36874ff019b38',
#    'department': 'Crew',
#    'job': 'Armorer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1866265,
#    'known_for_department': 'Art',
#    'name': "Helen O'Loan",
#    'original_name': "Helen O'Loan",
#    'popularity': 0.0973,
#    'profile_path': '/qiSdUI0YnaQ6gw4Fh0jrsVtdG6o.jpg',
#    'credit_id': '598a20d69251414bb401c312',
#    'department': 'Art',
#    'job': 'Set Designer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1347995,
#    'known_for_department': 'Art',
#    'name': 'Ross Perkin',
#    'original_name': 'Ross Perkin',
#    'popularity': 0.0633,
#    'profile_path': None,
#    'credit_id': '598a211cc3a36874ff019bd4',
#    'department': 'Art',
#    'job': 'Set Designer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866270,
#    'known_for_department': 'Art',
#    'name': 'Evan Shipard',
#    'original_name': 'Evan Shipard',
#    'popularity': 0.0481,
#    'profile_path': None,
#    'credit_id': '598a2181c3a368752601890f',
#    'department': 'Art',
#    'job': 'Conceptual Illustrator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866272,
#    'known_for_department': 'Crew',
#    'name': 'Eddy Taylor',
#    'original_name': 'Eddy Taylor',
#    'popularity': 0.0453,
#    'profile_path': None,
#    'credit_id': '598a21bd9251416b50019bb7',
#    'department': 'Crew',
#    'job': 'Propmaker'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1334496,
#    'known_for_department': 'Art',
#    'name': 'Ty Teiger',
#    'original_name': 'Ty Teiger',
#    'popularity': 0.1584,
#    'profile_path': None,
#    'credit_id': '598a21e7c3a36824a000da19',
#    'department': 'Art',
#    'job': 'Property Master'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866283,
#    'known_for_department': 'Art',
#    'name': 'Ron Wallekers',
#    'original_name': 'Ron Wallekers',
#    'popularity': 0.0908,
#    'profile_path': None,
#    'credit_id': '598a22649251416b50019c79',
#    'department': 'Art',
#    'job': 'Greensman'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866290,
#    'known_for_department': 'Art',
#    'name': 'Jack Whiddon',
#    'original_name': 'Jack Whiddon',
#    'popularity': 0.0398,
#    'profile_path': None,
#    'credit_id': '598a2294c3a36874f201d5a9',
#    'department': 'Art',
#    'job': 'Greensman'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866293,
#    'known_for_department': 'Crew',
#    'name': 'Peter Wyborn',
#    'original_name': 'Peter Wyborn',
#    'popularity': 0.0561,
#    'profile_path': None,
#    'credit_id': '598a22cfc3a368755f01d761',
#    'department': 'Crew',
#    'job': 'Propmaker'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1405232,
#    'known_for_department': 'Sound',
#    'name': 'Laura Harris Atkinson',
#    'original_name': 'Laura Harris Atkinson',
#    'popularity': 0.2583,
#    'profile_path': None,
#    'credit_id': '598a23249251414bac01cfbf',
#    'department': 'Sound',
#    'job': 'Dialogue Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1031811,
#    'known_for_department': 'Sound',
#    'name': 'Andrew DeCristofaro',
#    'original_name': 'Andrew DeCristofaro',
#    'popularity': 0.099,
#    'profile_path': '/ae2f2FrRojJQ5W1Rw8I0OaCq00g.jpg',
#    'credit_id': '598a236f9251416b50019d86',
#    'department': 'Sound',
#    'job': 'Supervising Sound Editor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1437193,
#    'known_for_department': 'Sound',
#    'name': 'Lauren Hadaway',
#    'original_name': 'Lauren Hadaway',
#    'popularity': 0.1103,
#    'profile_path': '/n8yvg8bs1wNBSu3DXvWDcC68hUr.jpg',
#    'credit_id': '598a23a3c3a3687526018ac3',
#    'department': 'Sound',
#    'job': 'ADR Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1406390,
#    'known_for_department': 'Sound',
#    'name': 'Dan Hegeman',
#    'original_name': 'Dan Hegeman',
#    'popularity': 0.1231,
#    'profile_path': None,
#    'credit_id': '598a23e0925141370600f17c',
#    'department': 'Sound',
#    'job': 'Sound Effects Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1116936,
#    'known_for_department': 'Sound',
#    'name': 'Nancy MacLeod',
#    'original_name': 'Nancy MacLeod',
#    'popularity': 0.1008,
#    'profile_path': None,
#    'credit_id': '598a24139251416b50019e19',
#    'department': 'Sound',
#    'job': 'Foley Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 95835,
#    'known_for_department': 'Sound',
#    'name': 'Eric A. Norris',
#    'original_name': 'Eric A. Norris',
#    'popularity': 0.306,
#    'profile_path': '/mksvxvfNqhFM8lsKSckosiOWYpq.jpg',
#    'credit_id': '598a24579251414bb401c675',
#    'department': 'Sound',
#    'job': 'Sound Designer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1404903,
#    'known_for_department': 'Sound',
#    'name': 'Becky Sullivan',
#    'original_name': 'Becky Sullivan',
#    'popularity': 0.2293,
#    'profile_path': None,
#    'credit_id': '598a24bac3a36874ff019f61',
#    'department': 'Sound',
#    'job': 'Supervising Sound Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866299,
#    'known_for_department': 'Sound',
#    'name': 'Mark van Kool',
#    'original_name': 'Mark van Kool',
#    'popularity': 0.0398,
#    'profile_path': None,
#    'credit_id': '598a24ed9251414bdd01bcfb',
#    'department': 'Sound',
#    'job': 'Boom Operator'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1377293,
#    'known_for_department': 'Sound',
#    'name': 'Karen Vassar Triest',
#    'original_name': 'Karen Vassar Triest',
#    'popularity': 0.1449,
#    'profile_path': None,
#    'credit_id': '598a2528c3a3687526018c3b',
#    'department': 'Sound',
#    'job': 'Sound Effects Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1390524,
#    'known_for_department': 'Sound',
#    'name': 'Jay Wilkinson',
#    'original_name': 'Jay Wilkinson',
#    'popularity': 0.1982,
#    'profile_path': None,
#    'credit_id': '598a255bc3a36874ff019ff9',
#    'department': 'Sound',
#    'job': 'Sound Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1866312,
#    'known_for_department': 'Visual Effects',
#    'name': 'Fahed Alhabib',
#    'original_name': 'Fahed Alhabib',
#    'popularity': 0.0718,
#    'profile_path': None,
#    'credit_id': '598a26119251414bac01d2e0',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866315,
#    'known_for_department': 'Visual Effects',
#    'name': 'Vaughn Arnup',
#    'original_name': 'Vaughn Arnup',
#    'popularity': 0.0757,
#    'profile_path': None,
#    'credit_id': '598a2760c3a36874f201dabc',
#    'department': 'Visual Effects',
#    'job': 'Roto Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1453960,
#    'known_for_department': 'Visual Effects',
#    'name': 'Lexie Busby',
#    'original_name': 'Lexie Busby',
#    'popularity': 0.0651,
#    'profile_path': None,
#    'credit_id': '598a2800c3a368755f01dd71',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1554365,
#    'known_for_department': 'Editing',
#    'name': 'Catherine Chase',
#    'original_name': 'Catherine Chase',
#    'popularity': 0.0956,
#    'profile_path': None,
#    'credit_id': '598a284ec3a36824e200e5e0',
#    'department': 'Crew',
#    'job': 'Visual Effects Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1453978,
#    'known_for_department': 'Visual Effects',
#    'name': 'Jeff Driver',
#    'original_name': 'Jeff Driver',
#    'popularity': 0.0176,
#    'profile_path': None,
#    'credit_id': '598a28bc9251414bdd01c156',
#    'department': 'Visual Effects',
#    'job': 'Modeling'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1463489,
#    'known_for_department': 'Visual Effects',
#    'name': 'Alexis Forni',
#    'original_name': 'Alexis Forni',
#    'popularity': 0.0214,
#    'profile_path': None,
#    'credit_id': '598a28fc9251414bac01d647',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 63289,
#    'known_for_department': 'Production',
#    'name': 'Steve Gaub',
#    'original_name': 'Steve Gaub',
#    'popularity': 0.0623,
#    'profile_path': None,
#    'credit_id': '598a29799251414bd101bab0',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866324,
#    'known_for_department': 'Visual Effects',
#    'name': 'Patrick Hernandez',
#    'original_name': 'Patrick Hernandez',
#    'popularity': 0.0362,
#    'profile_path': None,
#    'credit_id': '598a2a559251414bfa01b949',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866325,
#    'known_for_department': 'Visual Effects',
#    'name': 'Georgina Lovering',
#    'original_name': 'Georgina Lovering',
#    'popularity': 0.0409,
#    'profile_path': None,
#    'credit_id': '598a2ac0c3a36874ff01a540',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1414185,
#    'known_for_department': 'Crew',
#    'name': "Jenni O'Byrne",
#    'original_name': "Jenni O'Byrne",
#    'popularity': 0.087,
#    'profile_path': None,
#    'credit_id': '598a2b1e9251414bd101bc3a',
#    'department': 'Crew',
#    'job': 'Visual Effects Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1547204,
#    'known_for_department': 'Visual Effects',
#    'name': "Erin D. O'Connor",
#    'original_name': "Erin D. O'Connor",
#    'popularity': 0.1416,
#    'profile_path': None,
#    'credit_id': '598a2b699251414bac01d8dd',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866330,
#    'known_for_department': 'Visual Effects',
#    'name': 'Jane Reynolds',
#    'original_name': 'Jane Reynolds',
#    'popularity': 0.1201,
#    'profile_path': None,
#    'credit_id': '598a2c16925141329e01751a',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1568468,
#    'known_for_department': 'Visual Effects',
#    'name': 'Pascal Rigaud',
#    'original_name': 'Pascal Rigaud',
#    'popularity': 0.0774,
#    'profile_path': None,
#    'credit_id': '598a2c6ac3a368755f01e1eb',
#    'department': 'Visual Effects',
#    'job': 'VFX Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 9357,
#    'known_for_department': 'Crew',
#    'name': 'Glenn Boswell',
#    'original_name': 'Glenn Boswell',
#    'popularity': 0.1429,
#    'profile_path': '/pIsBLm6zLeMpjEkrQw4ICQgZ3OQ.jpg',
#    'credit_id': '598a2cc8925141329e0175d8',
#    'department': 'Crew',
#    'job': 'Stunt Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1644252,
#    'known_for_department': 'Camera',
#    'name': 'Peter Beeh',
#    'original_name': 'Peter Beeh',
#    'popularity': 0.0916,
#    'profile_path': None,
#    'credit_id': '598a2d339251414bb401cfc6',
#    'department': 'Camera',
#    'job': 'Aerial Camera'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1364623,
#    'known_for_department': 'Camera',
#    'name': 'Simon Christidis',
#    'original_name': 'Simon Christidis',
#    'popularity': 0.1656,
#    'profile_path': None,
#    'credit_id': '598a2d90c3a36874ff01a7cd',
#    'department': 'Camera',
#    'job': 'Underwater Director of Photography'},
#   {'adult': False,
#    'gender': 2,
#    'id': 151,
#    'known_for_department': 'Camera',
#    'name': 'Roger Deakins',
#    'original_name': 'Roger Deakins',
#    'popularity': 0.4902,
#    'profile_path': '/pSCN7CfILlfQrxX43Kgqrx5mBYQ.jpg',
#    'credit_id': '598a2db9c3a36874f201e1de',
#    'department': 'Camera',
#    'job': 'Camera Operator'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1569342,
#    'known_for_department': 'Camera',
#    'name': "Andrew 'A.J.' Johnson",
#    'original_name': "Andrew 'A.J.' Johnson",
#    'popularity': 0.1246,
#    'profile_path': None,
#    'credit_id': '598a2eac925141329e0177b7',
#    'department': 'Camera',
#    'job': 'Steadicam Operator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1395243,
#    'known_for_department': 'Camera',
#    'name': 'Vince Valitutti',
#    'original_name': 'Vince Valitutti',
#    'popularity': 0.1204,
#    'profile_path': None,
#    'credit_id': '598a2f3dc3a368752601955d',
#    'department': 'Camera',
#    'job': 'Still Photographer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1746452,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Bronwyn Doughty',
#    'original_name': 'Bronwyn Doughty',
#    'popularity': 0.0712,
#    'profile_path': None,
#    'credit_id': '598a2fc39251414bfa01bea3',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1195358,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Phil Eagles',
#    'original_name': 'Phil Eagles',
#    'popularity': 0.1434,
#    'profile_path': None,
#    'credit_id': '598a2ffc9251414bb401d2b9',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866353,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Jamella Hassan',
#    'original_name': 'Jamella Hassan',
#    'popularity': 0.0377,
#    'profile_path': None,
#    'credit_id': '598a3047c3a36824a000e797',
#    'department': 'Costume & Make-Up',
#    'job': 'Key Costumer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866356,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Tony Velasco',
#    'original_name': 'Tony Velasco',
#    'popularity': 0.1052,
#    'profile_path': None,
#    'credit_id': '598a30b19251416b5001aa77',
#    'department': 'Costume & Make-Up',
#    'job': 'Key Costumer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394306,
#    'known_for_department': 'Sound',
#    'name': 'Kenneth Karman',
#    'original_name': 'Kenneth Karman',
#    'popularity': 0.1451,
#    'profile_path': None,
#    'credit_id': '598a3152925141370600ffc0',
#    'department': 'Sound',
#    'job': 'Music Editor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1415642,
#    'known_for_department': 'Sound',
#    'name': 'Denise Okimoto',
#    'original_name': 'Denise Okimoto',
#    'popularity': 0.1257,
#    'profile_path': None,
#    'credit_id': '598a31a0c3a3687865018c88',
#    'department': 'Sound',
#    'job': 'Music Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866370,
#    'known_for_department': 'Production',
#    'name': 'Concepcion Alicino-Saucedo',
#    'original_name': 'Concepcion Alicino-Saucedo',
#    'popularity': 0.0923,
#    'profile_path': None,
#    'credit_id': '598a3211c3a368755f01e7e2',
#    'department': 'Production',
#    'job': 'Production Coordinator'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1565126,
#    'known_for_department': 'Production',
#    'name': 'Selena Carrillo',
#    'original_name': 'Selena Carrillo',
#    'popularity': 0.0978,
#    'profile_path': None,
#    'credit_id': '598a32b8c3a36874ff01ac96',
#    'department': 'Production',
#    'job': 'Production Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866374,
#    'known_for_department': 'Production',
#    'name': 'Nicholas Copping',
#    'original_name': 'Nicholas Copping',
#    'popularity': 0.0921,
#    'profile_path': None,
#    'credit_id': '598a330a9251414bfa01c1ee',
#    'department': 'Production',
#    'job': 'Production Coordinator'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1866376,
#    'known_for_department': 'Acting',
#    'name': 'Peter Kent',
#    'original_name': 'Peter Kent',
#    'popularity': 0.118,
#    'profile_path': None,
#    'credit_id': '598a33bbc3a3687865018f0e',
#    'department': 'Crew',
#    'job': 'Dialect Coach'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1866378,
#    'known_for_department': 'Crew',
#    'name': 'Scott Menzies',
#    'original_name': 'Scott Menzies',
#    'popularity': 0.0286,
#    'profile_path': None,
#    'credit_id': '598a33fdc3a36875260199df',
#    'department': 'Crew',
#    'job': 'Pilot'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1417021,
#    'known_for_department': 'Directing',
#    'name': 'James Ellis Deakins',
#    'original_name': 'James Ellis Deakins',
#    'popularity': 0.1037,
#    'profile_path': None,
#    'credit_id': '66316ee1470ead0125101588',
#    'department': 'Production',
#    'job': 'Production Consultant'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1402905,
#    'known_for_department': 'Production',
#    'name': 'Duncan Jones',
#    'original_name': 'Duncan Jones',
#    'popularity': 0.0833,
#    'profile_path': '/qNNp4wnRAPXfp8lM5PxTC2swFDM.jpg',
#    'credit_id': '5b24604b9251410d49000e71',
#    'department': 'Production',
#    'job': 'Location Manager'},
#   {'adult': False,
#    'gender': 1,
#    'id': 38268,
#    'known_for_department': 'Writing',
#    'name': 'Laura Hillenbrand',
#    'original_name': 'Laura Hillenbrand',
#    'popularity': 0.2602,
#    'profile_path': None,
#    'credit_id': '5c0e4461c3a36825280bf0e3',
#    'department': 'Writing',
#    'job': 'Book'},
#   {'adult': False,
#    'gender': 2,
#    'id': 54211,
#    'known_for_department': 'Production',
#    'name': 'Thomas Tull',
#    'original_name': 'Thomas Tull',
#    'popularity': 0.305,
#    'profile_path': '/gRvTHmNKEqzyt2sGvpjrAvmloy0.jpg',
#    'credit_id': '5c64818f0e0a267dfd9a7b62',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1711549,
#    'known_for_department': 'Sound',
#    'name': 'David Lee',
#    'original_name': 'David Lee',
#    'popularity': 0.1595,
#    'profile_path': None,
#    'credit_id': '5dacda583876510017ddf755',
#    'department': 'Sound',
#    'job': 'Production Sound Mixer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394131,
#    'known_for_department': 'Sound',
#    'name': 'Jon Taylor',
#    'original_name': 'Jon Taylor',
#    'popularity': 0.1818,
#    'profile_path': None,
#    'credit_id': '5d8a9165abf8e200297705bd',
#    'department': 'Sound',
#    'job': 'Sound Re-Recording Mixer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394130,
#    'known_for_department': 'Sound',
#    'name': 'Frank A. Montaño',
#    'original_name': 'Frank A. Montaño',
#    'popularity': 0.2691,
#    'profile_path': None,
#    'credit_id': '5d8a918079b3d4001f8605c9',
#    'department': 'Sound',
#    'job': 'Sound Re-Recording Mixer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2969953,
#    'known_for_department': 'Directing',
#    'name': 'Marieke Spence',
#    'original_name': 'Marieke Spence',
#    'popularity': 0.0701,
#    'profile_path': None,
#    'credit_id': '60217e5a263462003df9978f',
#    'department': 'Directing',
#    'job': 'Assistant Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1389139,
#    'known_for_department': 'Camera',
#    'name': 'David James',
#    'original_name': 'David James',
#    'popularity': 0.3003,
#    'profile_path': '/x9sjJDX6Ii3GMA6Kkt2upYHcgC.jpg',
#    'credit_id': '675d9d8a41f353ce086d0310',
#    'department': 'Camera',
#    'job': 'Still Photographer'}]}

# %%
df_crew = pd.DataFrame(df1['crew'].values[0])
df_crew
# Out:
#      adult  gender       id known_for_department                 name  \
# 0    False       1    11701               Acting       Angelina Jolie
# 1    False       2     1224            Directing           Ethan Coen
# 2    False       2     1223            Directing            Joel Coen
# 3    False       2     2163              Writing  Richard LaGravenese
# 4    False       0  1143709              Writing         Matthew Barr
# ..     ...     ...      ...                  ...                  ...
# 96   False       2  1711549                Sound            David Lee
# 97   False       2  1394131                Sound           Jon Taylor
# 98   False       2  1394130                Sound     Frank A. Montaño
# 99   False       1  2969953            Directing       Marieke Spence
# 100  False       2  1389139               Camera          David James
#
#            original_name  popularity                      profile_path  \
# 0         Angelina Jolie     10.9892  /bXNxIKcJ5cNNW8QFrBPWcfTSu9x.jpg
# 1             Ethan Coen      0.8290  /ccvoiEe3gEMAth1Oy8SJxVeMcAk.jpg
# 2              Joel Coen      0.6932  /rgVaJNkZCgMarUcZuUAsVfXMWk3.jpg
# 3    Richard LaGravenese      0.9239  /vCXgeY2gJXSSGTm9cy71268wGx5.jpg
# 4           Matthew Barr      0.0468                              None
# ..                   ...         ...                               ...
# 96             David Lee      0.1595                              None
# 97            Jon Taylor      0.1818                              None
# 98      Frank A. Montaño      0.2691                              None
# 99        Marieke Spence      0.0701                              None
# 100          David James      0.3003   /x9sjJDX6Ii3GMA6Kkt2upYHcgC.jpg
#
#                     credit_id  department                       job
# 0    52fe4e9d9251416c7515c817   Directing                  Director
# 1    52fe4e9d9251416c7515c81d     Writing                Screenplay
# 2    52fe4e9d9251416c7515c823     Writing                Screenplay
# 3    52fe4e9d9251416c7515c829     Writing                Screenplay
# 4    52fe4e9d9251416c7515c82f  Production                  Producer
# ..                        ...         ...                       ...
# 96   5dacda583876510017ddf755       Sound    Production Sound Mixer
# 97   5d8a9165abf8e200297705bd       Sound  Sound Re-Recording Mixer
# 98   5d8a918079b3d4001f8605c9       Sound  Sound Re-Recording Mixer
# 99   60217e5a263462003df9978f   Directing        Assistant Director
# 100  675d9d8a41f353ce086d0310      Camera        Still Photographer
#
# [101 rows x 11 columns]

# %%
# Credits

import requests

tmdb_id = 102651

url = f"https://api.themoviedb.org/3/movie/{tmdb_id}/credits?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"
}

response = requests.get(url, headers=headers)

data = response.json()

df1 = pd.json_normalize(data)
data
# Out:
# {'id': 102651,
#  'cast': [{'adult': False,
#    'gender': 1,
#    'id': 11701,
#    'known_for_department': 'Acting',
#    'name': 'Angelina Jolie',
#    'original_name': 'Angelina Jolie',
#    'popularity': 10.9892,
#    'profile_path': '/bXNxIKcJ5cNNW8QFrBPWcfTSu9x.jpg',
#    'cast_id': 7,
#    'character': 'Maleficent',
#    'credit_id': '52fe4a0cc3a36847f81b5cb3',
#    'order': 0},
#   {'adult': False,
#    'gender': 1,
#    'id': 18050,
#    'known_for_department': 'Acting',
#    'name': 'Elle Fanning',
#    'original_name': 'Elle Fanning',
#    'popularity': 5.8778,
#    'profile_path': '/e8CUyxQSE99y5IOfzSLtHC0B0Ch.jpg',
#    'cast_id': 6,
#    'character': 'Princess Aurora',
#    'credit_id': '52fe4a0cc3a36847f81b5caf',
#    'order': 1},
#   {'adult': False,
#    'gender': 1,
#    'id': 11356,
#    'known_for_department': 'Acting',
#    'name': 'Imelda Staunton',
#    'original_name': 'Imelda Staunton',
#    'popularity': 1.3628,
#    'profile_path': '/tABRYOHUQeaUCAqrelJV5ZHjl1W.jpg',
#    'cast_id': 16,
#    'character': 'Knotgrass',
#    'credit_id': '52fe4a0cc3a36847f81b5cd7',
#    'order': 2},
#   {'adult': False,
#    'gender': 2,
#    'id': 82191,
#    'known_for_department': 'Acting',
#    'name': 'Sharlto Copley',
#    'original_name': 'Sharlto Copley',
#    'popularity': 1.0401,
#    'profile_path': '/em89OJJvBRX7kNJJPASmNKQujsC.jpg',
#    'cast_id': 12,
#    'character': 'Stefan',
#    'credit_id': '52fe4a0cc3a36847f81b5cc7',
#    'order': 3},
#   {'adult': False,
#    'gender': 1,
#    'id': 72305,
#    'known_for_department': 'Acting',
#    'name': 'Lesley Manville',
#    'original_name': 'Lesley Manville',
#    'popularity': 1.1972,
#    'profile_path': '/tioPlSoypjdME3oMu3g7XmgIIKS.jpg',
#    'cast_id': 20,
#    'character': 'Flittle',
#    'credit_id': '52fe4a0cc3a36847f81b5ce7',
#    'order': 4},
#   {'adult': False,
#    'gender': 1,
#    'id': 36594,
#    'known_for_department': 'Acting',
#    'name': 'Juno Temple',
#    'original_name': 'Juno Temple',
#    'popularity': 2.44,
#    'profile_path': '/ntBw3aUZmIw9ObmsmvPgk1UKMd8.jpg',
#    'cast_id': 11,
#    'character': 'Thistletwit',
#    'credit_id': '52fe4a0cc3a36847f81b5cc3',
#    'order': 5},
#   {'adult': False,
#    'gender': 2,
#    'id': 32987,
#    'known_for_department': 'Acting',
#    'name': 'Sam Riley',
#    'original_name': 'Sam Riley',
#    'popularity': 0.6505,
#    'profile_path': '/cpym1mwaXMGvOCXy967hdp0oSgD.jpg',
#    'cast_id': 17,
#    'character': 'Diaval',
#    'credit_id': '52fe4a0cc3a36847f81b5cdb',
#    'order': 6},
#   {'adult': False,
#    'gender': 2,
#    'id': 1017347,
#    'known_for_department': 'Acting',
#    'name': 'Brenton Thwaites',
#    'original_name': 'Brenton Thwaites',
#    'popularity': 1.5022,
#    'profile_path': '/4jrtVjdIGJpmgevEPRuIIU9HWcO.jpg',
#    'cast_id': 15,
#    'character': 'Prince Phillip',
#    'credit_id': '52fe4a0cc3a36847f81b5cd3',
#    'order': 7},
#   {'adult': False,
#    'gender': 2,
#    'id': 26258,
#    'known_for_department': 'Acting',
#    'name': 'Kenneth Cranham',
#    'original_name': 'Kenneth Cranham',
#    'popularity': 0.6565,
#    'profile_path': '/9lzTbNgaoArlxpEkYtWQfOyiYwu.jpg',
#    'cast_id': 22,
#    'character': 'King Henry',
#    'credit_id': '52fe4a0cc3a36847f81b5cef',
#    'order': 8},
#   {'adult': False,
#    'gender': 1,
#    'id': 195286,
#    'known_for_department': 'Acting',
#    'name': 'Sarah Flind',
#    'original_name': 'Sarah Flind',
#    'popularity': 0.208,
#    'profile_path': '/lBa8fpzY0sUsfU10PjE7VWsEbvB.jpg',
#    'cast_id': 34,
#    'character': "Princess Leila's Handmaiden",
#    'credit_id': '55e41e56c3a368419a0037b7',
#    'order': 9},
#   {'adult': False,
#    'gender': 2,
#    'id': 2417829,
#    'known_for_department': 'Acting',
#    'name': 'Michael Higgins',
#    'original_name': 'Michael Higgins',
#    'popularity': 0.0256,
#    'profile_path': None,
#    'cast_id': 113,
#    'character': 'Young Stefan',
#    'credit_id': '5d8a01c3172d7f00174debfd',
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 1355733,
#    'known_for_department': 'Acting',
#    'name': 'Isobelle Molloy',
#    'original_name': 'Isobelle Molloy',
#    'popularity': 0.0979,
#    'profile_path': '/kZAE0ULtpjOVjxlgZC6PZFEENjY.jpg',
#    'cast_id': 25,
#    'character': 'Young Maleficent',
#    'credit_id': '53f7bf4f0e0a267a72000014',
#    'order': 11},
#   {'adult': False,
#    'gender': 2,
#    'id': 1502461,
#    'known_for_department': 'Acting',
#    'name': 'Jackson Bews',
#    'original_name': 'Jackson Bews',
#    'popularity': 0.2201,
#    'profile_path': '/of70BbE1KAq6J1PuUFnEHRyzh3Z.jpg',
#    'cast_id': 35,
#    'character': 'Teen Stefan',
#    'credit_id': '55e41e5692514137da0038f7',
#    'order': 12},
#   {'adult': False,
#    'gender': 2,
#    'id': 1833,
#    'known_for_department': 'Acting',
#    'name': 'Jamie Sives',
#    'original_name': 'Jamie Sives',
#    'popularity': 0.5061,
#    'profile_path': '/bdEyp4f1VUEepihC6vyqCGP6k2s.jpg',
#    'cast_id': 19,
#    'character': 'Shepherd',
#    'credit_id': '52fe4a0cc3a36847f81b5ce3',
#    'order': 13},
#   {'adult': False,
#    'gender': 2,
#    'id': 933640,
#    'known_for_department': 'Acting',
#    'name': 'Angus Wright',
#    'original_name': 'Angus Wright',
#    'popularity': 0.2675,
#    'profile_path': '/7VOW55b8WF0eyFJiCjiBXSRA5mG.jpg',
#    'cast_id': 36,
#    'character': 'Advisor to King Henry',
#    'credit_id': '55e41e57c3a3684191003bce',
#    'order': 14},
#   {'adult': False,
#    'gender': 1,
#    'id': 1258225,
#    'known_for_department': 'Acting',
#    'name': 'Hannah New',
#    'original_name': 'Hannah New',
#    'popularity': 0.5101,
#    'profile_path': '/5n6177kkkgD3LeWjXl8VZGVXm6Y.jpg',
#    'cast_id': 23,
#    'character': 'Princess Leila',
#    'credit_id': '53b422de0e0a26598c00cd9f',
#    'order': 15},
#   {'adult': False,
#    'gender': 2,
#    'id': 65451,
#    'known_for_department': 'Acting',
#    'name': 'Oliver Maltman',
#    'original_name': 'Oliver Maltman',
#    'popularity': 0.308,
#    'profile_path': '/wZgJ4BhseHlGOakiSMLCDUE07ic.jpg',
#    'cast_id': 37,
#    'character': 'Advisor to King Henry',
#    'credit_id': '55e41e5792514137ec0036a9',
#    'order': 16},
#   {'adult': False,
#    'gender': 2,
#    'id': 230697,
#    'known_for_department': 'Acting',
#    'name': 'Gary Cargill',
#    'original_name': 'Gary Cargill',
#    'popularity': 0.1257,
#    'profile_path': '/lTVH6MlfuFFFcB0xF9U5WEKV9FI.jpg',
#    'cast_id': 38,
#    'character': 'Nobleman',
#    'credit_id': '55e41e57c3a3684191003bd0',
#    'order': 17},
#   {'adult': False,
#    'gender': 0,
#    'id': 140525,
#    'known_for_department': 'Acting',
#    'name': "John O'Toole",
#    'original_name': "John O'Toole",
#    'popularity': 0.0617,
#    'profile_path': None,
#    'cast_id': 39,
#    'character': 'Nobleman',
#    'credit_id': '55e41e5892514137da0038fb',
#    'order': 18},
#   {'adult': False,
#    'gender': 1,
#    'id': 47627,
#    'known_for_department': 'Acting',
#    'name': 'Janet McTeer',
#    'original_name': 'Janet McTeer',
#    'popularity': 1.2242,
#    'profile_path': '/qOKAI6aunD4J5MXiwwomAhI3jI2.jpg',
#    'cast_id': 56,
#    'character': 'Narrator (voice)',
#    'credit_id': '55e41e5d92514137e30035e7',
#    'order': 19},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502462,
#    'known_for_department': 'Acting',
#    'name': 'Harry Attwell',
#    'original_name': 'Harry Attwell',
#    'popularity': 0.0796,
#    'profile_path': None,
#    'cast_id': 40,
#    'character': 'Nobleman',
#    'credit_id': '55e41e58c3a368418800339a',
#    'order': 20},
#   {'adult': False,
#    'gender': 2,
#    'id': 139811,
#    'known_for_department': 'Acting',
#    'name': 'Mark Caven',
#    'original_name': 'Mark Caven',
#    'popularity': 0.1949,
#    'profile_path': '/8OvM4N3TcGlGr803XsKVmIku2pE.jpg',
#    'cast_id': 44,
#    'character': 'General',
#    'credit_id': '55e41e59c3a368418800339e',
#    'order': 21},
#   {'adult': False,
#    'gender': 2,
#    'id': 96281,
#    'known_for_department': 'Acting',
#    'name': 'James Hicks',
#    'original_name': 'James Hicks',
#    'popularity': 0.1359,
#    'profile_path': '/yMhzoQOWWnhpv8xPpLxo07tnWqw.jpg',
#    'cast_id': 42,
#    'character': 'Military Nobleman',
#    'credit_id': '55e41e58c3a36841970037bc',
#    'order': 22},
#   {'adult': False,
#    'gender': 2,
#    'id': 115622,
#    'known_for_department': 'Acting',
#    'name': 'Anthony May',
#    'original_name': 'Anthony May',
#    'popularity': 0.1181,
#    'profile_path': None,
#    'cast_id': 41,
#    'character': 'Nobleman',
#    'credit_id': '55e41e5892514137e30035e5',
#    'order': 23},
#   {'adult': False,
#    'gender': 2,
#    'id': 185003,
#    'known_for_department': 'Acting',
#    'name': 'Stephan Chase',
#    'original_name': 'Stephan Chase',
#    'popularity': 0.2499,
#    'profile_path': '/6OYHrDkTyRmF2jVxhuPYXVTXmUb.jpg',
#    'cast_id': 43,
#    'character': 'General',
#    'credit_id': '55e41e5992514137da0038fd',
#    'order': 24},
#   {'adult': False,
#    'gender': 2,
#    'id': 1238441,
#    'known_for_department': 'Acting',
#    'name': 'Chris Leaney',
#    'original_name': 'Chris Leaney',
#    'popularity': 0.0453,
#    'profile_path': '/5vuNQ9g9TsA8PtaKbG2wqypeQVA.jpg',
#    'cast_id': 45,
#    'character': 'Servant in Wing Room',
#    'credit_id': '55e41e5992514137e900353f',
#    'order': 25},
#   {'adult': False,
#    'gender': 2,
#    'id': 145071,
#    'known_for_department': 'Acting',
#    'name': 'Jamie Maclachlan',
#    'original_name': 'Jamie Maclachlan',
#    'popularity': 0.1598,
#    'profile_path': '/oE0O4BjDMwD4j4EBedS0eOvhcv0.jpg',
#    'cast_id': 46,
#    'character': 'Soldier in Wood',
#    'credit_id': '55e41e5ac3a36841880033a0',
#    'order': 26},
#   {'adult': False,
#    'gender': 1,
#    'id': 1502463,
#    'known_for_department': 'Acting',
#    'name': 'Vivienne Jolie-Pitt',
#    'original_name': 'Vivienne Jolie-Pitt',
#    'popularity': 0.1485,
#    'profile_path': '/sD9JCQJn4natJ2hm4sr3AE9a3tr.jpg',
#    'cast_id': 47,
#    'character': 'Aurora (5 yrs.)',
#    'credit_id': '55e41e5ac3a368419400373a',
#    'order': 27},
#   {'adult': False,
#    'gender': 1,
#    'id': 1462923,
#    'known_for_department': 'Acting',
#    'name': 'Eleanor Worthington-Cox',
#    'original_name': 'Eleanor Worthington-Cox',
#    'popularity': 0.3458,
#    'profile_path': '/jc3Dtrxff8huEkeXnntitCDaJWa.jpg',
#    'cast_id': 48,
#    'character': 'Aurora (8 yrs.)',
#    'credit_id': '55e41e5b92514137e6003623',
#    'order': 28},
#   {'adult': False,
#    'gender': 2,
#    'id': 550549,
#    'known_for_department': 'Acting',
#    'name': 'John Macmillan',
#    'original_name': 'John Macmillan',
#    'popularity': 0.7974,
#    'profile_path': '/o9Jtr3vLCF3ZNPaQ7oMM4oLtmLh.jpg',
#    'cast_id': 49,
#    'character': 'Captain',
#    'credit_id': '55e41e5bc3a3684191003bd3',
#    'order': 29},
#   {'adult': False,
#    'gender': 2,
#    'id': 1001523,
#    'known_for_department': 'Acting',
#    'name': 'Tim Treloar',
#    'original_name': 'Tim Treloar',
#    'popularity': 0.1105,
#    'profile_path': '/bZrvMVInpWyLgkuortLrhyZUQA5.jpg',
#    'cast_id': 50,
#    'character': 'Farmer',
#    'credit_id': '55e41e5bc3a368418b0033ee',
#    'order': 30},
#   {'adult': False,
#    'gender': 0,
#    'id': 568393,
#    'known_for_department': 'Acting',
#    'name': 'Peter G. Reed',
#    'original_name': 'Peter G. Reed',
#    'popularity': 0.0813,
#    'profile_path': None,
#    'cast_id': 51,
#    'character': 'Guard (voice)',
#    'credit_id': '55e41e5bc3a368419400373e',
#    'order': 31},
#   {'adult': False,
#    'gender': 1,
#    'id': 1312266,
#    'known_for_department': 'Acting',
#    'name': 'Marama Corlett',
#    'original_name': 'Marama Corlett',
#    'popularity': 0.2377,
#    'profile_path': '/kLIwpT5Vn6AIad4z6O9pgzMOv5u.jpg',
#    'cast_id': 52,
#    'character': 'Servant',
#    'credit_id': '55e41e5c92514137e9003542',
#    'order': 32},
#   {'adult': False,
#    'gender': 2,
#    'id': 75065,
#    'known_for_department': 'Acting',
#    'name': 'Liam McKenna',
#    'original_name': 'Liam McKenna',
#    'popularity': 0.1069,
#    'profile_path': None,
#    'cast_id': 53,
#    'character': "King Henry's Captain",
#    'credit_id': '55e41e5cc3a3684191003bd5',
#    'order': 33},
#   {'adult': False,
#    'gender': 2,
#    'id': 1102427,
#    'known_for_department': 'Acting',
#    'name': 'Steven Cree',
#    'original_name': 'Steven Cree',
#    'popularity': 0.6414,
#    'profile_path': '/oH9uSQMJPdFHeVggqvMwheW7nZl.jpg',
#    'cast_id': 54,
#    'character': 'Overseer',
#    'credit_id': '55e41e5c92514137dd0035a9',
#    'order': 34},
#   {'adult': False,
#    'gender': 1,
#    'id': 91023,
#    'known_for_department': 'Acting',
#    'name': 'Sandy Fox',
#    'original_name': 'Sandy Fox',
#    'popularity': 0.169,
#    'profile_path': '/5M4B03lQ73DFyqIUbAxHhVaafu5.jpg',
#    'cast_id': 55,
#    'character': 'Fairies / Creatures (voice)',
#    'credit_id': '55e41e5dc3a368418b0033f0',
#    'order': 35},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502464,
#    'known_for_department': 'Acting',
#    'name': 'James Ayling',
#    'original_name': 'James Ayling',
#    'popularity': 0.0239,
#    'profile_path': None,
#    'cast_id': 59,
#    'character': 'Stefans Guard (uncredited)',
#    'credit_id': '55e41e5ec3a3684185003531',
#    'order': 36},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502466,
#    'known_for_department': 'Acting',
#    'name': 'Raf Cross',
#    'original_name': 'Raf Cross',
#    'popularity': 0.0286,
#    'profile_path': None,
#    'cast_id': 63,
#    'character': 'Young Man (uncredited)',
#    'credit_id': '55e41e60c3a36841880033a4',
#    'order': 37},
#   {'adult': False,
#    'gender': 0,
#    'id': 1430707,
#    'known_for_department': 'Acting',
#    'name': 'Alfred Camp',
#    'original_name': 'Alfred Camp',
#    'popularity': 0.0256,
#    'profile_path': None,
#    'cast_id': 62,
#    'character': "King Henry's General (uncredited)",
#    'credit_id': '55e41e5f92514137da003903',
#    'order': 38},
#   {'adult': False,
#    'gender': 1,
#    'id': 186605,
#    'known_for_department': 'Production',
#    'name': 'Terri Douglas',
#    'original_name': 'Terri Douglas',
#    'popularity': 0.6133,
#    'profile_path': '/6yRCc5oKalchZuRvVJJbEDNmLEd.jpg',
#    'cast_id': 65,
#    'character': 'Curse Voice, Fairies, Creatures (uncredited)',
#    'credit_id': '55e41e60c3a36841970037bf',
#    'order': 39},
#   {'adult': False,
#    'gender': 2,
#    'id': 1502468,
#    'known_for_department': 'Acting',
#    'name': 'Damon Driver',
#    'original_name': 'Damon Driver',
#    'popularity': 0.0563,
#    'profile_path': '/l04IyeiBfztccOSgJiXLE1cpLkc.jpg',
#    'cast_id': 66,
#    'character': 'Court Jester (uncredited)',
#    'credit_id': '55e41e6192514137dd0035ad',
#    'order': 40},
#   {'adult': False,
#    'gender': 2,
#    'id': 1502469,
#    'known_for_department': 'Crew',
#    'name': 'Josh Dyer',
#    'original_name': 'Josh Dyer',
#    'popularity': 0.1136,
#    'profile_path': '/9qv3HhF8q6BAEpSoCJ3Np7mkxDI.jpg',
#    'cast_id': 67,
#    'character': "Stefan's Soldier / Henry's Soldier (uncredited)",
#    'credit_id': '55e41e61c3a3684191003bda',
#    'order': 41},
#   {'adult': False,
#    'gender': 1,
#    'id': 1502470,
#    'known_for_department': 'Acting',
#    'name': 'Stephanie Elstob',
#    'original_name': 'Stephanie Elstob',
#    'popularity': 0.0718,
#    'profile_path': '/1PL7A3EqBr1mLch7Lpm0MAltz0Q.jpg',
#    'cast_id': 68,
#    'character': 'Dancer (uncredited)',
#    'credit_id': '55e41e6192514137e30035ec',
#    'order': 42},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502471,
#    'known_for_department': 'Acting',
#    'name': 'Ellis Fuller',
#    'original_name': 'Ellis Fuller',
#    'popularity': 0.0168,
#    'profile_path': None,
#    'cast_id': 69,
#    'character': 'Courtier (uncredited)',
#    'credit_id': '55e41e61c3a368418e00317b',
#    'order': 43},
#   {'adult': False,
#    'gender': 2,
#    'id': 1502472,
#    'known_for_department': 'Acting',
#    'name': 'Craig Garner',
#    'original_name': 'Craig Garner',
#    'popularity': 0.123,
#    'profile_path': '/feCc4hA6jnumtlevnHZSGAKZpr3.jpg',
#    'cast_id': 70,
#    'character': 'Blue Suit Performer (uncredited)',
#    'credit_id': '55e41e6292514137ec0036ae',
#    'order': 44},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394404,
#    'known_for_department': 'Acting',
#    'name': 'Alexander Gillison',
#    'original_name': 'Alexander Gillison',
#    'popularity': 0.0143,
#    'profile_path': None,
#    'cast_id': 71,
#    'character': "King Henry's Soldier (uncredited)",
#    'credit_id': '55e41e62c3a3684185003535',
#    'order': 45},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502473,
#    'known_for_department': 'Acting',
#    'name': 'Victoria Gugenheim',
#    'original_name': 'Victoria Gugenheim',
#    'popularity': 0.0071,
#    'profile_path': None,
#    'cast_id': 72,
#    'character': 'Courtier (uncredited)',
#    'credit_id': '55e41e62c3a368418b0033f4',
#    'order': 46},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502474,
#    'known_for_department': 'Acting',
#    'name': 'Daniel Harland',
#    'original_name': 'Daniel Harland',
#    'popularity': 0.0563,
#    'profile_path': None,
#    'cast_id': 73,
#    'character': 'Courtier (uncredited)',
#    'credit_id': '55e41e6392514137da00390c',
#    'order': 47},
#   {'adult': False,
#    'gender': 1,
#    'id': 1347128,
#    'known_for_department': 'Acting',
#    'name': 'Kara Lily Hayworth',
#    'original_name': 'Kara Lily Hayworth',
#    'popularity': 0.0869,
#    'profile_path': None,
#    'cast_id': 74,
#    'character': 'Pixie Reader (uncredited)',
#    'credit_id': '55e41e6392514137e6003627',
#    'order': 48},
#   {'adult': False,
#    'gender': 2,
#    'id': 1375518,
#    'known_for_department': 'Acting',
#    'name': 'John Heartstone',
#    'original_name': 'John Heartstone',
#    'popularity': 0.0747,
#    'profile_path': '/5ei7MVhCGWhznauEinrFWMNQZeM.jpg',
#    'cast_id': 75,
#    'character': 'Soldier / Courtier (uncredited)',
#    'credit_id': '55e41e63c3a3684194003741',
#    'order': 49},
#   {'adult': False,
#    'gender': 2,
#    'id': 1075104,
#    'known_for_department': 'Acting',
#    'name': 'Matt Hookings',
#    'original_name': 'Matt Hookings',
#    'popularity': 0.09,
#    'profile_path': '/iPmO808tQE0Pm52vQFhevRGZIEn.jpg',
#    'cast_id': 76,
#    'character': "Stefan's Soldier (uncredited)",
#    'credit_id': '55e41e6492514137d7003643',
#    'order': 50},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502475,
#    'known_for_department': 'Acting',
#    'name': 'Craig Izzard',
#    'original_name': 'Craig Izzard',
#    'popularity': 0.0404,
#    'profile_path': None,
#    'cast_id': 77,
#    'character': "King Henry's Soldier (uncredited)",
#    'credit_id': '55e41e64c3a3684191003be0',
#    'order': 51},
#   {'adult': False,
#    'gender': 1,
#    'id': 1502476,
#    'known_for_department': 'Acting',
#    'name': 'Ceri Jerome',
#    'original_name': 'Ceri Jerome',
#    'popularity': 0.0582,
#    'profile_path': '/16jmKlOw2wcNhj5tU6lHXrGRuym.jpg',
#    'cast_id': 78,
#    'character': 'Dancer (uncredited)',
#    'credit_id': '55e41e6492514137e000358e',
#    'order': 52},
#   {'adult': False,
#    'gender': 1,
#    'id': 1242871,
#    'known_for_department': 'Acting',
#    'name': 'Zahara Jolie-Pitt',
#    'original_name': 'Zahara Jolie-Pitt',
#    'popularity': 0.0927,
#    'profile_path': None,
#    'cast_id': 79,
#    'character': 'Girl (uncredited)',
#    'credit_id': '55e41e64c3a3684185003537',
#    'order': 53},
#   {'adult': False,
#    'gender': 2,
#    'id': 1502477,
#    'known_for_department': 'Acting',
#    'name': 'Lee Edward Jones',
#    'original_name': 'Lee Edward Jones',
#    'popularity': 0.0286,
#    'profile_path': None,
#    'cast_id': 80,
#    'character': 'Blue Suit Performer (uncredited)',
#    'credit_id': '55e41e65c3a368418b0033fa',
#    'order': 54},
#   {'adult': False,
#    'gender': 0,
#    'id': 1378466,
#    'known_for_department': 'Acting',
#    'name': 'Hrvoje Klecz',
#    'original_name': 'Hrvoje Klecz',
#    'popularity': 0.078,
#    'profile_path': None,
#    'cast_id': 81,
#    'character': 'Courtier (uncredited)',
#    'credit_id': '55e41e6592514137dd0035b2',
#    'order': 55},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502478,
#    'known_for_department': 'Acting',
#    'name': 'Karen Mkrtchyan',
#    'original_name': 'Karen Mkrtchyan',
#    'popularity': 0.0143,
#    'profile_path': None,
#    'cast_id': 84,
#    'character': 'Courtier (uncredited)',
#    'credit_id': '55e41e66c3a36841970037c2',
#    'order': 56},
#   {'adult': False,
#    'gender': 2,
#    'id': 1207207,
#    'known_for_department': 'Acting',
#    'name': 'João Costa Menezes',
#    'original_name': 'João Costa Menezes',
#    'popularity': 0.184,
#    'profile_path': '/c6c38XQz3SjX5sF5jWHnm7dWh4E.jpg',
#    'cast_id': 83,
#    'character': 'Palace Guard (uncredited)',
#    'credit_id': '55e41e6692514137da003910',
#    'order': 57},
#   {'adult': False,
#    'gender': 2,
#    'id': 1502479,
#    'known_for_department': 'Acting',
#    'name': 'Matthew John Morley',
#    'original_name': 'Matthew John Morley',
#    'popularity': 0.0193,
#    'profile_path': '/20CpbztbtcwK5QEBXgAQtVH8jVD.jpg',
#    'cast_id': 85,
#    'character': "King Stefan's Army (uncredited)",
#    'credit_id': '55e41e6692514137e600362a',
#    'order': 58},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502480,
#    'known_for_department': 'Acting',
#    'name': 'Steven John Nice',
#    'original_name': 'Steven John Nice',
#    'popularity': 0.0239,
#    'profile_path': None,
#    'cast_id': 86,
#    'character': 'Courtier (uncredited)',
#    'credit_id': '55e41e67c3a368418b0033ff',
#    'order': 59},
#   {'adult': False,
#    'gender': 1,
#    'id': 1278771,
#    'known_for_department': 'Acting',
#    'name': 'Jo Osmond',
#    'original_name': 'Jo Osmond',
#    'popularity': 0.0929,
#    'profile_path': '/6cTye3OgvI2DCHwVNLqND1A9zQv.jpg',
#    'cast_id': 88,
#    'character': 'Blue Suit Performer (uncredited)',
#    'credit_id': '55e41e67c3a36841970037c6',
#    'order': 60},
#   {'adult': False,
#    'gender': 0,
#    'id': 1279742,
#    'known_for_department': 'Acting',
#    'name': 'Andrew James Porter',
#    'original_name': 'Andrew James Porter',
#    'popularity': 0.0336,
#    'profile_path': None,
#    'cast_id': 89,
#    'character': "King Henry's Soldier (uncredited)",
#    'credit_id': '55e41e6792514137d7003645',
#    'order': 61},
#   {'adult': False,
#    'gender': 0,
#    'id': 1462424,
#    'known_for_department': 'Acting',
#    'name': 'Guy Potter',
#    'original_name': 'Guy Potter',
#    'popularity': 0.0398,
#    'profile_path': None,
#    'cast_id': 90,
#    'character': "Stefan's Page (uncredited)",
#    'credit_id': '55e41e68c3a3684191003be4',
#    'order': 62},
#   {'adult': False,
#    'gender': 0,
#    'id': 1502481,
#    'known_for_department': 'Acting',
#    'name': 'Marc Rolfe',
#    'original_name': 'Marc Rolfe',
#    'popularity': 0.0363,
#    'profile_path': None,
#    'cast_id': 91,
#    'character': 'King Stefans Guard (uncredited)',
#    'credit_id': '55e41e6892514137e0003594',
#    'order': 63},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394408,
#    'known_for_department': 'Acting',
#    'name': 'JD Roth-Round',
#    'original_name': 'JD Roth-Round',
#    'popularity': 0.0256,
#    'profile_path': None,
#    'cast_id': 92,
#    'character': 'Palace Guard (uncredited)',
#    'credit_id': '55e41e68c3a368419a0037bd',
#    'order': 64},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394409,
#    'known_for_department': 'Acting',
#    'name': 'Julian Seager',
#    'original_name': 'Julian Seager',
#    'popularity': 0.1878,
#    'profile_path': '/lIv4g7FcmJWErnuBdpfnFF2N3tF.jpg',
#    'cast_id': 93,
#    'character': "Stefan's General (uncredited)",
#    'credit_id': '55e41e6992514137e900354b',
#    'order': 65},
#   {'adult': False,
#    'gender': 2,
#    'id': 1481440,
#    'known_for_department': 'Acting',
#    'name': 'Daniel Stisen',
#    'original_name': 'Daniel Stisen',
#    'popularity': 0.3388,
#    'profile_path': '/jhyIFfBnM5nLhHdpFiGIW6qk9x5.jpg',
#    'cast_id': 95,
#    'character': 'Screen Combat, Soldier (uncredited)',
#    'credit_id': '55e41e6992514137da003913',
#    'order': 66},
#   {'adult': False,
#    'gender': 2,
#    'id': 1502483,
#    'known_for_department': 'Acting',
#    'name': 'Leo Suter',
#    'original_name': 'Leo Suter',
#    'popularity': 0.7822,
#    'profile_path': '/vRFLpAz9k01M4TwEvgXao8AkXFf.jpg',
#    'cast_id': 97,
#    'character': 'Young Man (uncredited)',
#    'credit_id': '55e41e6ac3a368419400374c',
#    'order': 67},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394377,
#    'known_for_department': 'Acting',
#    'name': 'Tom Swacha',
#    'original_name': 'Tom Swacha',
#    'popularity': 0.0839,
#    'profile_path': None,
#    'cast_id': 98,
#    'character': 'Courtier (uncredited)',
#    'credit_id': '55e41e6a92514137e600362f',
#    'order': 68},
#   {'adult': False,
#    'gender': 0,
#    'id': 1438979,
#    'known_for_department': 'Acting',
#    'name': 'Richard Summers-Calvert',
#    'original_name': 'Richard Summers-Calvert',
#    'popularity': 0.0708,
#    'profile_path': None,
#    'cast_id': 96,
#    'character': 'Stefan Guard (uncredited)',
#    'credit_id': '55e41e6ac3a368418b003404',
#    'order': 69}],
#  'crew': [{'adult': False,
#    'gender': 1,
#    'id': 8386,
#    'known_for_department': 'Production',
#    'name': 'Sarah Bradshaw',
#    'original_name': 'Sarah Bradshaw',
#    'popularity': 0.1216,
#    'profile_path': None,
#    'credit_id': '52fe4a0cc3a36847f81b5c9f',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 23424,
#    'known_for_department': 'Production',
#    'name': 'Lucy Bevan',
#    'original_name': 'Lucy Bevan',
#    'popularity': 0.2404,
#    'profile_path': '/hT17FBbxl9gXD5IdieHKoydRcb4.jpg',
#    'credit_id': '52fe4a0cc3a36847f81b5cab',
#    'department': 'Production',
#    'job': 'Casting'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1032536,
#    'known_for_department': 'Visual Effects',
#    'name': 'Robert Stromberg',
#    'original_name': 'Robert Stromberg',
#    'popularity': 0.2399,
#    'profile_path': '/wmg5MgMd3Kx9Tk7QQbV9GLg30yd.jpg',
#    'credit_id': '52fe4a0cc3a36847f81b5cb9',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 1,
#    'id': 38792,
#    'known_for_department': 'Writing',
#    'name': 'Linda Woolverton',
#    'original_name': 'Linda Woolverton',
#    'popularity': 0.2848,
#    'profile_path': '/AagHXmW37oiLSCsUYIifAaFfkz.jpg',
#    'credit_id': '52fe4a0cc3a36847f81b5cbf',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2151819,
#    'known_for_department': 'Crew',
#    'name': 'Caridad Angus',
#    'original_name': 'Caridad Angus',
#    'popularity': 0.0779,
#    'profile_path': None,
#    'credit_id': '62a2e1ec53866e4f7fa27b45',
#    'department': 'Crew',
#    'job': 'Stand In'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1012323,
#    'known_for_department': 'Sound',
#    'name': 'Sammy Fain',
#    'original_name': 'Sammy Fain',
#    'popularity': 0.1592,
#    'profile_path': None,
#    'credit_id': '651a94ad072166011c01f6a0',
#    'department': 'Sound',
#    'job': 'Songs'},
#   {'adult': False,
#    'gender': 2,
#    'id': 163297,
#    'known_for_department': 'Writing',
#    'name': 'Tom Adair',
#    'original_name': 'Tom Adair',
#    'popularity': 0.1273,
#    'profile_path': None,
#    'credit_id': '651a9549ea84c700aeea8738',
#    'department': 'Sound',
#    'job': 'Songs'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3975204,
#    'known_for_department': 'Sound',
#    'name': 'Jack Lawrence',
#    'original_name': 'Jack Lawrence',
#    'popularity': 0.0357,
#    'profile_path': None,
#    'credit_id': '651a9616ea84c700eb9a21b5',
#    'department': 'Sound',
#    'job': 'Songs'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1339446,
#    'known_for_department': 'Sound',
#    'name': 'Frank E. Eulner',
#    'original_name': 'Frank E. Eulner',
#    'popularity': 0.2195,
#    'profile_path': '/w1kMhUQmksPKFjlmRcQY7buzGF3.jpg',
#    'credit_id': '65150b4ccadb6b02bc0ba87f',
#    'department': 'Sound',
#    'job': 'Supervising Sound Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394129,
#    'known_for_department': 'Sound',
#    'name': 'Tim Nielsen',
#    'original_name': 'Tim Nielsen',
#    'popularity': 0.2343,
#    'profile_path': '/xjaI8e0itWAzGCWTj3VW2Wa8uoQ.jpg',
#    'credit_id': '65150b59cadb6b02be54fcdf',
#    'department': 'Sound',
#    'job': 'Sound Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1394129,
#    'known_for_department': 'Sound',
#    'name': 'Tim Nielsen',
#    'original_name': 'Tim Nielsen',
#    'popularity': 0.2343,
#    'profile_path': '/xjaI8e0itWAzGCWTj3VW2Wa8uoQ.jpg',
#    'credit_id': '65150b671db65d00e31c0ed7',
#    'department': 'Sound',
#    'job': 'Supervising Sound Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1406614,
#    'known_for_department': 'Sound',
#    'name': 'David Parker',
#    'original_name': 'David Parker',
#    'popularity': 0.1704,
#    'profile_path': '/bDGLVWQShONQ59fvwKqP6dtFxT5.jpg',
#    'credit_id': '65150b8fc50ad200ad7ee9f9',
#    'department': 'Sound',
#    'job': 'Sound Re-Recording Mixer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 138618,
#    'known_for_department': 'Sound',
#    'name': 'Gary Rizzo',
#    'original_name': 'Gary Rizzo',
#    'popularity': 0.1781,
#    'profile_path': '/m8vT9fYRLwM8WPpJiq8QIMBSueQ.jpg',
#    'credit_id': '65150bacea84c7010c11338b',
#    'department': 'Sound',
#    'job': 'Sound Re-Recording Mixer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1213,
#    'known_for_department': 'Sound',
#    'name': 'James Newton Howard',
#    'original_name': 'James Newton Howard',
#    'popularity': 0.7041,
#    'profile_path': '/qB4JgzCXCjr7NwW7UNrgBrWZDlo.jpg',
#    'credit_id': '543eb4b5c3a368250a0028c5',
#    'department': 'Sound',
#    'job': 'Original Music Composer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 11301,
#    'known_for_department': 'Crew',
#    'name': 'Lucy Allen',
#    'original_name': 'Lucy Allen',
#    'popularity': 0.2682,
#    'profile_path': '/jBgDb9MSM3NkxlP9dMcHY37IDIU.jpg',
#    'credit_id': '6549a26e6beaea014b69621f',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1452995,
#    'known_for_department': 'Visual Effects',
#    'name': 'Stewart Alves',
#    'original_name': 'Stewart Alves',
#    'popularity': 0.1576,
#    'profile_path': None,
#    'credit_id': '552c5c7892514174db0002cf',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1454884,
#    'known_for_department': 'Visual Effects',
#    'name': 'Cedric Nicolas-Troyan',
#    'original_name': 'Cedric Nicolas-Troyan',
#    'popularity': 0.2188,
#    'profile_path': '/e5r1BokTOBfCSaAJd69whUTTGOT.jpg',
#    'credit_id': '552f5f15c3a368220e0014a0',
#    'department': 'Directing',
#    'job': 'Assistant Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2056368,
#    'known_for_department': 'Crew',
#    'name': 'Tolga Kenan',
#    'original_name': 'Tolga Kenan',
#    'popularity': 0.3843,
#    'profile_path': '/tXAIMG59IeXHay1Z33B3BhzM11d.jpg',
#    'credit_id': '6555822f0816c700abbcd2a5',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 2,
#    'id': 3511645,
#    'known_for_department': 'Crew',
#    'name': 'Marc Mailley',
#    'original_name': 'Marc Mailley',
#    'popularity': 0.2056,
#    'profile_path': '/hpJY25YMdRAnKKVafYYqztpP50T.jpg',
#    'credit_id': '65558af59653f613f864995e',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1460603,
#    'known_for_department': 'Crew',
#    'name': 'Dhumal Sagar',
#    'original_name': 'Dhumal Sagar',
#    'popularity': 0.0838,
#    'profile_path': None,
#    'credit_id': '554ec43b92514162f5000072',
#    'department': 'Crew',
#    'job': 'Compositors'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1447542,
#    'known_for_department': 'Crew',
#    'name': 'Erik Classen',
#    'original_name': 'Erik Classen',
#    'popularity': 0.1052,
#    'profile_path': None,
#    'credit_id': '554fb323c3a3681870005427',
#    'department': 'Crew',
#    'job': 'Compositors'},
#   {'adult': False,
#    'gender': 2,
#    'id': 4501,
#    'known_for_department': 'Camera',
#    'name': 'Dean Semler',
#    'original_name': 'Dean Semler',
#    'popularity': 0.307,
#    'profile_path': '/6GewzjGfuCc6fsf4f2ZsmDWp4Dl.jpg',
#    'credit_id': '55a77d9592514125da0011b2',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 2,
#    'id': 12824,
#    'known_for_department': 'Production',
#    'name': 'Don Hahn',
#    'original_name': 'Don Hahn',
#    'popularity': 0.3719,
#    'profile_path': '/rOUyA2JG3yN2Sh4ICZoGYShU5ox.jpg',
#    'credit_id': '656f25f5886348014d85fdd3',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 18311,
#    'known_for_department': 'Production',
#    'name': 'Joe Roth',
#    'original_name': 'Joe Roth',
#    'popularity': 0.3566,
#    'profile_path': '/xLWXgnO7f3298NQawL9ctjA1uUZ.jpg',
#    'credit_id': '656f2603568463010f8492bb',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 928399,
#    'known_for_department': 'Production',
#    'name': 'Palak Patel',
#    'original_name': 'Palak Patel',
#    'popularity': 0.0739,
#    'profile_path': None,
#    'credit_id': '656f261c880551011d1f1dd0',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2230759,
#    'known_for_department': 'Art',
#    'name': 'Rob Bliss',
#    'original_name': 'Rob Bliss',
#    'popularity': 0.1124,
#    'profile_path': None,
#    'credit_id': '65b3116ba199a601309daebc',
#    'department': 'Art',
#    'job': 'Concept Artist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1530865,
#    'known_for_department': 'Production',
#    'name': 'Michael Vieira',
#    'original_name': 'Michael Vieira',
#    'popularity': 0.0393,
#    'profile_path': None,
#    'credit_id': '65b36e5bb3316b0130a09a9a',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 6688,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Anna B. Sheppard',
#    'original_name': 'Anna B. Sheppard',
#    'popularity': 0.1148,
#    'profile_path': '/k3bznaLxtBMltY2A0AvJnNk3IP3.jpg',
#    'credit_id': '65b36eaab3316b0164a0be8d',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Designer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 8386,
#    'known_for_department': 'Production',
#    'name': 'Sarah Bradshaw',
#    'original_name': 'Sarah Bradshaw',
#    'popularity': 0.1216,
#    'profile_path': None,
#    'credit_id': '65b36f2db3316b0164a0bf12',
#    'department': 'Production',
#    'job': 'Unit Production Manager'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1553728,
#    'known_for_department': 'Production',
#    'name': 'Simone Goodridge',
#    'original_name': 'Simone Goodridge',
#    'popularity': 0.0679,
#    'profile_path': None,
#    'credit_id': '65b36f5d00213401317bab09',
#    'department': 'Production',
#    'job': 'Unit Production Manager'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1117749,
#    'known_for_department': 'Directing',
#    'name': 'Richard Whelan',
#    'original_name': 'Richard Whelan',
#    'popularity': 0.0826,
#    'profile_path': None,
#    'credit_id': '65b36f765541fa0164b14381',
#    'department': 'Directing',
#    'job': 'First Assistant Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2622523,
#    'known_for_department': 'Production',
#    'name': 'Samar Pollitt',
#    'original_name': 'Samar Pollitt',
#    'popularity': 0.073,
#    'profile_path': None,
#    'credit_id': '65b36f8ed236e60163bff0cb',
#    'department': 'Directing',
#    'job': 'Second Assistant Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1393323,
#    'known_for_department': 'Visual Effects',
#    'name': 'Barrie Hemsley',
#    'original_name': 'Barrie Hemsley',
#    'popularity': 0.0963,
#    'profile_path': None,
#    'credit_id': '65b36fbd5e14e501830c3a85',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 142325,
#    'known_for_department': 'Crew',
#    'name': 'Simon Crane',
#    'original_name': 'Simon Crane',
#    'popularity': 0.5771,
#    'profile_path': '/9tRVvRYQnHWdh9glTHhgXkkjbHe.jpg',
#    'credit_id': '65b36fde9ba86a01832fe699',
#    'department': 'Directing',
#    'job': 'Second Unit Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 142325,
#    'known_for_department': 'Crew',
#    'name': 'Simon Crane',
#    'original_name': 'Simon Crane',
#    'popularity': 0.5771,
#    'profile_path': '/9tRVvRYQnHWdh9glTHhgXkkjbHe.jpg',
#    'credit_id': '65b37002b3316b0185a0cf1a',
#    'department': 'Crew',
#    'job': 'Stunt Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1034755,
#    'known_for_department': 'Crew',
#    'name': 'Lori Korngiebel',
#    'original_name': 'Lori Korngiebel',
#    'popularity': 0.089,
#    'profile_path': None,
#    'credit_id': '65b37023a0f1a2017abe54df',
#    'department': 'Production',
#    'job': 'Associate Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2077296,
#    'known_for_department': 'Production',
#    'name': 'Zack Roth',
#    'original_name': 'Zack Roth',
#    'popularity': 0.078,
#    'profile_path': None,
#    'credit_id': '65b3703900213401857be0c2',
#    'department': 'Production',
#    'job': 'Associate Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 44217,
#    'known_for_department': 'Writing',
#    'name': 'Charles Perrault',
#    'original_name': 'Charles Perrault',
#    'popularity': 0.3226,
#    'profile_path': '/g6FQdZTTlI6r1nmS6ZgJ6w25yI6.jpg',
#    'credit_id': '65b3706d9ba86a01622fc7b5',
#    'department': 'Writing',
#    'job': 'Book'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2151821,
#    'known_for_department': 'Crew',
#    'name': 'Sarah Lochlan',
#    'original_name': 'Sarah Lochlan',
#    'popularity': 0.1653,
#    'profile_path': '/oEnUndENW5LBe4jyePVob8L0aON.jpg',
#    'credit_id': '65d39343dc86470185c7f6f6',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 1,
#    'id': 11701,
#    'known_for_department': 'Acting',
#    'name': 'Angelina Jolie',
#    'original_name': 'Angelina Jolie',
#    'popularity': 10.9892,
#    'profile_path': '/bXNxIKcJ5cNNW8QFrBPWcfTSu9x.jpg',
#    'credit_id': '58cf90499251415a39031f8d',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 9646,
#    'known_for_department': 'Editing',
#    'name': 'Richard Pearson',
#    'original_name': 'Richard Pearson',
#    'popularity': 0.1656,
#    'profile_path': '/2KFTaD8j3zJUPe7KKhSdtzz7AZU.jpg',
#    'credit_id': '64104a5fede1b028e84ce35a',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 579551,
#    'known_for_department': 'Acting',
#    'name': 'Lana Del Rey',
#    'original_name': 'Lana Del Rey',
#    'popularity': 0.723,
#    'profile_path': '/wpwC6oB5WD8BijO4G9vsUn69NNY.jpg',
#    'credit_id': '661086a667dcc901639ad363',
#    'department': 'Sound',
#    'job': 'Songs'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1996002,
#    'known_for_department': 'Art',
#    'name': 'Rick Newsome',
#    'original_name': 'Rick Newsome',
#    'popularity': 0.1193,
#    'profile_path': None,
#    'credit_id': '5aa54cbcc3a3687bfc026aea',
#    'department': 'Art',
#    'job': 'Storyboard Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2038955,
#    'known_for_department': 'Crew',
#    'name': 'Nicholas Daines',
#    'original_name': 'Nicholas Daines',
#    'popularity': 0.1714,
#    'profile_path': '/mZz9J78mgdGCL0rdhFAiNzxrDSy.jpg',
#    'credit_id': '5af246b70e0a26688e004644',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 1,
#    'id': 237411,
#    'known_for_department': 'Crew',
#    'name': 'Nellie Burroughes',
#    'original_name': 'Nellie Burroughes',
#    'popularity': 0.1897,
#    'profile_path': '/A3gOCRPDKIZQpiVddbEwCokr5na.jpg',
#    'credit_id': '64a62442c3bffe014450f15f',
#    'department': 'Crew',
#    'job': 'Stunt Double'},
#   {'adult': False,
#    'gender': 2,
#    'id': 541,
#    'known_for_department': 'Editing',
#    'name': 'Chris Lebenzon',
#    'original_name': 'Chris Lebenzon',
#    'popularity': 0.2505,
#    'profile_path': '/eA6NqE5wdIM0LT3g1ihanv5vUM7.jpg',
#    'credit_id': '5b59d2f70e0a2611ed01297c',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 995644,
#    'known_for_department': 'Art',
#    'name': 'Dylan Cole',
#    'original_name': 'Dylan Cole',
#    'popularity': 0.1113,
#    'profile_path': None,
#    'credit_id': '5b59d33d9251414d15011275',
#    'department': 'Art',
#    'job': 'Production Design'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1322138,
#    'known_for_department': 'Art',
#    'name': 'Gary Freeman',
#    'original_name': 'Gary Freeman',
#    'popularity': 0.1223,
#    'profile_path': None,
#    'credit_id': '5b59d34d9251414d13011615',
#    'department': 'Art',
#    'job': 'Production Design'},
#   {'adult': False,
#    'gender': 2,
#    'id': 37301,
#    'known_for_department': 'Art',
#    'name': 'Frank Walsh',
#    'original_name': 'Frank Walsh',
#    'popularity': 0.1889,
#    'profile_path': None,
#    'credit_id': '5b59d35d9251414d28011433',
#    'department': 'Art',
#    'job': 'Supervising Art Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1325212,
#    'known_for_department': 'Art',
#    'name': 'Lee Sandales',
#    'original_name': 'Lee Sandales',
#    'popularity': 0.2063,
#    'profile_path': None,
#    'credit_id': '5b59d36fc3a36801e5012425',
#    'department': 'Art',
#    'job': 'Set Decoration'},
#   {'adult': False,
#    'gender': 2,
#    'id': 16178,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Rick Baker',
#    'original_name': 'Rick Baker',
#    'popularity': 0.4386,
#    'profile_path': '/8thqXBS5CQF0U2zsHAVM9GH7i4I.jpg',
#    'credit_id': '5b59d390c3a36801da013931',
#    'department': 'Costume & Make-Up',
#    'job': 'Makeup Artist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1415986,
#    'known_for_department': 'Camera',
#    'name': 'Fraser Taggart',
#    'original_name': 'Fraser Taggart',
#    'popularity': 0.2038,
#    'profile_path': '/yHeHwqEtEIrsoowL2r3D2Oj3Zop.jpg',
#    'credit_id': '64bad4d04d23dd00c814b85e',
#    'department': 'Camera',
#    'job': 'Second Unit Director of Photography'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1425530,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'John Norster',
#    'original_name': 'John Norster',
#    'popularity': 0.1556,
#    'profile_path': None,
#    'credit_id': '66c57834d663924e5adfdcbe',
#    'department': 'Costume & Make-Up',
#    'job': 'Assistant Costume Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1611353,
#    'known_for_department': 'Production',
#    'name': 'Matt Smith',
#    'original_name': 'Matt Smith',
#    'popularity': 0.132,
#    'profile_path': '/bql3Yg0VKD5uu0j1VzM46SM407x.jpg',
#    'credit_id': '5c62a38f0e0a267df197cc23',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1427569,
#    'known_for_department': 'Visual Effects',
#    'name': 'Jerad Marantz',
#    'original_name': 'Jerad Marantz',
#    'popularity': 0.2136,
#    'profile_path': None,
#    'credit_id': '5f296d1d9f37b000352c485d',
#    'department': 'Visual Effects',
#    'job': 'Character Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1458580,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kelly Port',
#    'original_name': 'Kelly Port',
#    'popularity': 0.1351,
#    'profile_path': '/1hdYNSeveVWBsrIfca7HkKXphJ8.jpg',
#    'credit_id': '66dc5dc8be21f92cda9db7e8',
#    'department': 'Visual Effects',
#    'job': 'Senior Visual Effects Supervisor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2769366,
#    'known_for_department': 'Crew',
#    'name': 'Christina Petrou',
#    'original_name': 'Christina Petrou',
#    'popularity': 0.2311,
#    'profile_path': '/dC7JHx7Q9qKa4YqdCZVvqYTUTSP.jpg',
#    'credit_id': '670158f26fc74e5756f84ccd',
#    'department': 'Crew',
#    'job': 'Stunt Double'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2270892,
#    'known_for_department': 'Crew',
#    'name': 'Michael Byrch',
#    'original_name': 'Michael Byrch',
#    'popularity': 0.216,
#    'profile_path': None,
#    'credit_id': '6733daa4916a0c1700964173',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1835518,
#    'known_for_department': 'Crew',
#    'name': 'Pete Ford',
#    'original_name': 'Pete Ford',
#    'popularity': 0.2277,
#    'profile_path': '/fYk6JB8piE8jgo5x9kJ3uvinKxG.jpg',
#    'credit_id': '6733eaec79280b32169f054b',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 1,
#    'id': 989325,
#    'known_for_department': 'Acting',
#    'name': 'Ella Purnell',
#    'original_name': 'Ella Purnell',
#    'popularity': 4.4578,
#    'profile_path': '/5PscK9HNXGFQMIxkpbR8ObB7vuR.jpg',
#    'credit_id': '6752228084ca928d00c9f6c6',
#    'department': 'Crew',
#    'job': 'Stunt Double'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1426479,
#    'known_for_department': 'Crew',
#    'name': 'Ryan Stuart',
#    'original_name': 'Ryan Stuart',
#    'popularity': 0.1212,
#    'profile_path': '/gmt8HAlDFV9AUW2AoNZqKCprysH.jpg',
#    'credit_id': '6760717dae81a3e434782ec3',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1992656,
#    'known_for_department': 'Crew',
#    'name': 'Cristian Knight',
#    'original_name': 'Cristian Knight',
#    'popularity': 0.2052,
#    'profile_path': '/8Vm03kiiiOoTlSJOrdmu7UlVyzR.jpg',
#    'credit_id': '67755bc297aa8e4e2c129ddd',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1335552,
#    'known_for_department': 'Art',
#    'name': 'Tom Whitehead',
#    'original_name': 'Tom Whitehead',
#    'popularity': 0.0779,
#    'profile_path': None,
#    'credit_id': '677d51d215cafe8aad74b77b',
#    'department': 'Art',
#    'job': 'Assistant Art Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2487730,
#    'known_for_department': 'Crew',
#    'name': 'Elliot Hawkes',
#    'original_name': 'Elliot Hawkes',
#    'popularity': 0.1552,
#    'profile_path': '/1tJUdoNm0iOjA9ubvjbkpiLX8pg.jpg',
#    'credit_id': '679917e0ba4f941f448f4852',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1625155,
#    'known_for_department': 'Crew',
#    'name': 'Levan Doran',
#    'original_name': 'Levan Doran',
#    'popularity': 0.2378,
#    'profile_path': '/7MfCdxrM33N2CEvVEcReaEf4Mf1.jpg',
#    'credit_id': '67a56565f196a73ae7670396',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1767631,
#    'known_for_department': 'Production',
#    'name': 'David Zealey',
#    'original_name': 'David Zealey',
#    'popularity': 0.0327,
#    'profile_path': None,
#    'credit_id': '67d17f0564443984b11e03e8',
#    'department': 'Production',
#    'job': 'Production Coordinator'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2151824,
#    'known_for_department': 'Crew',
#    'name': 'Annabel Wood',
#    'original_name': 'Annabel Wood',
#    'popularity': 0.1973,
#    'profile_path': '/4CHKGGBERzaTL3I2NkB4a4w4v9p.jpg',
#    'credit_id': '67e807a1a3d8cc928e67c90a',
#    'department': 'Crew',
#    'job': 'Stunts'}]}

# %%
df_cast = pd.DataFrame(df1['cast'].values[0])
df_cast
# Out:
#     adult  gender       id known_for_department                     name  \
# 0   False       1    11701               Acting           Angelina Jolie
# 1   False       1    18050               Acting             Elle Fanning
# 2   False       1    11356               Acting          Imelda Staunton
# 3   False       2    82191               Acting           Sharlto Copley
# 4   False       1    72305               Acting          Lesley Manville
# ..    ...     ...      ...                  ...                      ...
# 65  False       2  1394409               Acting            Julian Seager
# 66  False       2  1481440               Acting            Daniel Stisen
# 67  False       2  1502483               Acting                Leo Suter
# 68  False       0  1394377               Acting               Tom Swacha
# 69  False       0  1438979               Acting  Richard Summers-Calvert
#
#               original_name  popularity                      profile_path  \
# 0            Angelina Jolie     10.9892  /bXNxIKcJ5cNNW8QFrBPWcfTSu9x.jpg
# 1              Elle Fanning      5.8778  /e8CUyxQSE99y5IOfzSLtHC0B0Ch.jpg
# 2           Imelda Staunton      1.3628  /tABRYOHUQeaUCAqrelJV5ZHjl1W.jpg
# 3            Sharlto Copley      1.0401  /em89OJJvBRX7kNJJPASmNKQujsC.jpg
# 4           Lesley Manville      1.1972  /tioPlSoypjdME3oMu3g7XmgIIKS.jpg
# ..                      ...         ...                               ...
# 65            Julian Seager      0.1878  /lIv4g7FcmJWErnuBdpfnFF2N3tF.jpg
# 66            Daniel Stisen      0.3388  /jhyIFfBnM5nLhHdpFiGIW6qk9x5.jpg
# 67                Leo Suter      0.7822  /vRFLpAz9k01M4TwEvgXao8AkXFf.jpg
# 68               Tom Swacha      0.0839                              None
# 69  Richard Summers-Calvert      0.0708                              None
#
#     cast_id                            character                 credit_id  \
# 0         7                           Maleficent  52fe4a0cc3a36847f81b5cb3
# 1         6                      Princess Aurora  52fe4a0cc3a36847f81b5caf
# 2        16                            Knotgrass  52fe4a0cc3a36847f81b5cd7
# 3        12                               Stefan  52fe4a0cc3a36847f81b5cc7
# 4        20                              Flittle  52fe4a0cc3a36847f81b5ce7
# ..      ...                                  ...                       ...
# 65       93        Stefan's General (uncredited)  55e41e6992514137e900354b
# 66       95  Screen Combat, Soldier (uncredited)  55e41e6992514137da003913
# 67       97               Young Man (uncredited)  55e41e6ac3a368419400374c
# 68       98                Courtier (uncredited)  55e41e6a92514137e600362f
# 69       96            Stefan Guard (uncredited)  55e41e6ac3a368418b003404
#
#     order
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
# ..    ...
# 65     65
# 66     66
# 67     67
# 68     68
# 69     69
#
# [70 rows x 12 columns]

# %%
# Person

import requests

url = "https://api.themoviedb.org/3/search/person?query=tom%20hanks&include_adult=false&language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'gender': 2,
#    'id': 31,
#    'known_for_department': 'Acting',
#    'name': 'Tom Hanks',
#    'original_name': 'Tom Hanks',
#    'popularity': 7.8071,
#    'profile_path': '/eKF1sGJRrZJbfBG1KirPt1cfNd3.jpg',
#    'known_for': [{'backdrop_path': '/ghgfzbEV7kbpbi1O8eIILKVXEA8.jpg',
#      'id': 13,
#      'title': 'Forrest Gump',
#      'original_title': 'Forrest Gump',
#      'overview': 'A man with a low IQ has accomplished great things in his life and been present during significant historic events—in each case, far exceeding what anyone imagined he could do. But despite all he has achieved, his one true love eludes him.',
#      'poster_path': '/arw2vcBveWOVZr6pxd9XTd1TdQa.jpg',
#      'media_type': 'movie',
#      'adult': False,
#      'original_language': 'en',
#      'genre_ids': [35, 18, 10749],
#      'popularity': 24.5042,
#      'release_date': '1994-06-23',
#      'video': False,
#      'vote_average': 8.468,
#      'vote_count': 28084},
#     {'backdrop_path': '/3Rfvhy1Nl6sSGJwyjb0QiZzZYlB.jpg',
#      'id': 862,
#      'title': 'Toy Story',
#      'original_title': 'Toy Story',
#      'overview': "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.",
#      'poster_path': '/uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg',
#      'media_type': 'movie',
#      'adult': False,
#      'original_language': 'en',
#      'genre_ids': [16, 12, 10751, 35],
#      'popularity': 28.8943,
#      'release_date': '1995-11-22',
#      'video': False,
#      'vote_average': 7.968,
#      'vote_count': 18746},
#     {'backdrop_path': '/vxJ08SvwomfKbpboCWynC3uqUg4.jpg',
#      'id': 497,
#      'title': 'The Green Mile',
#      'original_title': 'The Green Mile',
#      'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#      'poster_path': '/8VG8fDNiy50H4FedGwdSVUPoaJe.jpg',
#      'media_type': 'movie',
#      'adult': False,
#      'original_language': 'en',
#      'genre_ids': [14, 18, 80],
#      'popularity': 20.8367,
#      'release_date': '1999-12-10',
#      'video': False,
#      'vote_average': 8.505,
#      'vote_count': 17994}]},
#   {'adult': False,
#    'gender': 0,
#    'id': 1156014,
#    'known_for_department': 'Directing',
#    'name': 'Tom Hankins',
#    'original_name': 'Tom Hankins',
#    'popularity': 0.0,
#    'profile_path': None,
#    'known_for': [{'backdrop_path': None,
#      'id': 173251,
#      'title': "Mac 'n Cheese",
#      'original_title': "Mac 'n Cheese",
#      'overview': "When you find yourself running scared and running out of energy, there's only a few options left to outrun your opponent through the southern desert. Stopping at nothing, watch these two guys wear each other out and rip through boundaries hitherto unbroken. Enjoy the ride.",
#      'poster_path': None,
#      'media_type': 'movie',
#      'adult': False,
#      'original_language': 'xx',
#      'genre_ids': [16, 28],
#      'popularity': 0.0071,
#      'release_date': '2011-08-08',
#      'video': False,
#      'vote_average': 5.3,
#      'vote_count': 6},
#     {'backdrop_path': None,
#      'id': 207000,
#      'title': "Mac 'n' Cheese: Supermarket",
#      'original_title': "Mac 'n' Cheese: Supermarket",
#      'overview': "Mac 'n Cheese try to realize their dream vacation by working in a local supermarket. Things go awry when new opportunities arise to make a buck. This short was shown theatrically before World War Z in the Netherlands.",
#      'poster_path': None,
#      'media_type': 'movie',
#      'adult': False,
#      'original_language': 'xx',
#      'genre_ids': [16, 28],
#      'popularity': 0.0261,
#      'release_date': '2013-06-20',
#      'video': False,
#      'vote_average': 5.5,
#      'vote_count': 2}]}],
#  'total_pages': 1,
#  'total_results': 2}

# %%
import requests

url = "https://api.themoviedb.org/3/person/7879?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'adult': False,
#  'also_known_as': ['John Alan Lasseter', '约翰·拉塞特', '約翰·拉薩特'],
#  'biography': 'John Alan Lasseter is an American film director, producer, screenwriter, animator, voice actor, and the head of animation at Skydance Animation. He was previously the chief creative officer of Pixar Animation Studios, Walt Disney Animation Studios, and Disneytoon Studios, as well as the Principal Creative Advisor for Walt Disney Imagineering.\n\nLasseter\'s first job was with The Walt Disney Company, where he became an animator. Next, he joined Lucasfilm, where he worked on the then-groundbreaking use of CGI animation. After Lucasfilm became Pixar in 1986, Lasseter oversaw all of Pixar\'s films and associated projects as executive producer and he directed Toy Story, A Bug\'s Life, Toy Story 2, Cars, "Toy Story 3" and "Cars 2".\n\nHe has won two Academy Awards, for Animated Short Film (Tin Toy), as well as a Special Achievement Award (Toy Story).',
#  'birthday': '1957-01-12',
#  'deathday': None,
#  'gender': 2,
#  'homepage': None,
#  'id': 7879,
#  'imdb_id': 'nm0005124',
#  'known_for_department': 'Production',
#  'name': 'John Lasseter',
#  'place_of_birth': 'Hollywood, Los Angeles, California, USA',
#  'popularity': 0.7459,
#  'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'}

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNWEzMGJmNWQyYmU5YzdiNzUwNTQ5ZTc3NTc1YTQ5OCIsIm5iZiI6MTc0Mjc0ODk0Ny44LCJzdWIiOiI2N2UwM2QxMzIxMGZhODBhMGY0ZGE4NzMiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.3Jf337Oe9cB_nBG4kCFfxnLYNpEXcm13G92QoBJSf2k"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 47.5065,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.708,
#    'vote_count': 28126},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 43.2221,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.687,
#    'vote_count': 21327},
#   {'adult': False,
#    'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#    'genre_ids': [18, 80],
#    'id': 240,
#    'original_language': 'en',
#    'original_title': 'The Godfather Part II',
#    'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#    'popularity': 21.3116,
#    'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#    'release_date': '1974-12-20',
#    'title': 'The Godfather Part II',
#    'video': False,
#    'vote_average': 8.57,
#    'vote_count': 12895},
#   {'adult': False,
#    'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#    'genre_ids': [18, 36, 10752],
#    'id': 424,
#    'original_language': 'en',
#    'original_title': "Schindler's List",
#    'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#    'popularity': 26.4391,
#    'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#    'release_date': '1993-12-15',
#    'title': "Schindler's List",
#    'video': False,
#    'vote_average': 8.564,
#    'vote_count': 16356},
#   {'adult': False,
#    'backdrop_path': '/bxgTSUenZDHNFerQ1whRKplrMKF.jpg',
#    'genre_ids': [18],
#    'id': 389,
#    'original_language': 'en',
#    'original_title': '12 Angry Men',
#    'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#    'popularity': 17.0012,
#    'poster_path': '/ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg',
#    'release_date': '1957-04-10',
#    'title': '12 Angry Men',
#    'video': False,
#    'vote_average': 8.548,
#    'vote_count': 9070},
#   {'adult': False,
#    'backdrop_path': '/6oaL4DP75yABrd5EbC4H2zq5ghc.jpg',
#    'genre_ids': [16, 10751, 14],
#    'id': 129,
#    'original_language': 'ja',
#    'original_title': '千と千尋の神隠し',
#    'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#    'popularity': 31.5408,
#    'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#    'release_date': '2001-07-20',
#    'title': 'Spirited Away',
#    'video': False,
#    'vote_average': 8.537,
#    'vote_count': 17034},
#   {'adult': False,
#    'backdrop_path': '/oOv2oUXcAaNXakRqUPxYq5lJURz.jpg',
#    'genre_ids': [18, 28, 80, 53],
#    'id': 155,
#    'original_language': 'en',
#    'original_title': 'The Dark Knight',
#    'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#    'popularity': 36.2811,
#    'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#    'release_date': '2008-07-16',
#    'title': 'The Dark Knight',
#    'video': False,
#    'vote_average': 8.519,
#    'vote_count': 33707},
#   {'adult': False,
#    'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 8.5912,
#    'poster_path': '/lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg',
#    'release_date': '1995-10-20',
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'video': False,
#    'vote_average': 8.516,
#    'vote_count': 4482},
#   {'adult': False,
#    'backdrop_path': '/vxJ08SvwomfKbpboCWynC3uqUg4.jpg',
#    'genre_ids': [14, 18, 80],
#    'id': 497,
#    'original_language': 'en',
#    'original_title': 'The Green Mile',
#    'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#    'popularity': 23.3805,
#    'poster_path': '/8VG8fDNiy50H4FedGwdSVUPoaJe.jpg',
#    'release_date': '1999-12-10',
#    'title': 'The Green Mile',
#    'video': False,
#    'vote_average': 8.504,
#    'vote_count': 17999},
#   {'adult': False,
#    'backdrop_path': '/hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg',
#    'genre_ids': [35, 53, 18],
#    'id': 496243,
#    'original_language': 'ko',
#    'original_title': '기생충',
#    'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#    'popularity': 33.1208,
#    'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#    'release_date': '2019-05-30',
#    'title': 'Parasite',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 18927},
#   {'adult': False,
#    'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#    'genre_ids': [53, 80],
#    'id': 680,
#    'original_language': 'en',
#    'original_title': 'Pulp Fiction',
#    'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#    'popularity': 27.1079,
#    'poster_path': '/vQWk5YBFWF4bZaofAbv0tShwBvQ.jpg',
#    'release_date': '1994-09-10',
#    'title': 'Pulp Fiction',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 28556},
#   {'adult': False,
#    'backdrop_path': '/8x9iKH8kWA0zdkgNdpAew7OstYe.jpg',
#    'genre_ids': [16, 10749, 18],
#    'id': 372058,
#    'original_language': 'ja',
#    'original_title': '君の名は。',
#    'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#    'popularity': 24.8851,
#    'poster_path': '/8GJsy7w7frGquw1cy9jasOGNNI1.jpg',
#    'release_date': '2016-08-26',
#    'title': 'Your Name.',
#    'video': False,
#    'vote_average': 8.485,
#    'vote_count': 11715},
#   {'adult': False,
#    'backdrop_path': '/2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg',
#    'genre_ids': [12, 14, 28],
#    'id': 122,
#    'original_language': 'en',
#    'original_title': 'The Lord of the Rings: The Return of the King',
#    'overview': 'As armies mass for a final battle that will decide the fate of the world--and powerful, ancient forces of Light and Dark compete to determine the outcome--one member of the Fellowship of the Ring is revealed as the noble heir to the throne of the Kings of Men. Yet, the sole hope for triumph over evil lies with a brave hobbit, Frodo, who, accompanied by his loyal friend Sam and the hideous, wretched Gollum, ventures deep into the very dark heart of Mordor on his seemingly impossible quest to destroy the Ring of Power.\u200b',
#    'popularity': 29.2191,
#    'poster_path': '/rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg',
#    'release_date': '2003-12-17',
#    'title': 'The Lord of the Rings: The Return of the King',
#    'video': False,
#    'vote_average': 8.483,
#    'vote_count': 24962},
#   {'adult': False,
#    'backdrop_path': '/ghgfzbEV7kbpbi1O8eIILKVXEA8.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 13,
#    'original_language': 'en',
#    'original_title': 'Forrest Gump',
#    'overview': 'A man with a low IQ has accomplished great things in his life and been present during significant historic events—in each case, far exceeding what anyone imagined he could do. But despite all he has achieved, his one true love eludes him.',
#    'popularity': 27.1331,
#    'poster_path': '/arw2vcBveWOVZr6pxd9XTd1TdQa.jpg',
#    'release_date': '1994-06-23',
#    'title': 'Forrest Gump',
#    'video': False,
#    'vote_average': 8.468,
#    'vote_count': 28092},
#   {'adult': False,
#    'backdrop_path': '/x4biAVdPVCghBlsVIzB6NmbghIz.jpg',
#    'genre_ids': [37],
#    'id': 429,
#    'original_language': 'it',
#    'original_title': 'Il buono, il brutto, il cattivo',
#    'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#    'popularity': 32.1239,
#    'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#    'release_date': '1966-12-22',
#    'title': 'The Good, the Bad and the Ugly',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 8934},
#   {'adult': False,
#    'backdrop_path': '/sJNNMCc6B7KZIY3LH3JMYJJNH5j.jpg',
#    'genre_ids': [28, 18],
#    'id': 346,
#    'original_language': 'ja',
#    'original_title': '七人の侍',
#    'overview': "A samurai answers a village's request for protection after he falls on hard times. The town needs protection from bandits, so the samurai gathers six others to help him teach the people how to defend themselves, and the villagers provide the soldiers with food.",
#    'popularity': 7.5098,
#    'poster_path': '/8OKmBV5BUFzmozIC3pPWKHy17kx.jpg',
#    'release_date': '1954-04-26',
#    'title': 'Seven Samurai',
#    'video': False,
#    'vote_average': 8.458,
#    'vote_count': 3864},
#   {'adult': False,
#    'backdrop_path': '/7TF4p86ZafnxFuNqWdhpHXFO244.jpg',
#    'genre_ids': [18, 80],
#    'id': 769,
#    'original_language': 'en',
#    'original_title': 'GoodFellas',
#    'overview': 'The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.',
#    'popularity': 21.5423,
#    'poster_path': '/aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg',
#    'release_date': '1990-09-12',
#    'title': 'GoodFellas',
#    'video': False,
#    'vote_average': 8.456,
#    'vote_count': 13285},
#   {'adult': False,
#    'backdrop_path': '/8sNiAPPYU14PUepFNeSNGUTiHW.jpg',
#    'genre_ids': [12, 18, 878],
#    'id': 157336,
#    'original_language': 'en',
#    'original_title': 'Interstellar',
#    'overview': 'The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.',
#    'popularity': 46.2046,
#    'poster_path': '/gEU2QniE6E77NI6lCU6MxlNBvIx.jpg',
#    'release_date': '2014-11-05',
#    'title': 'Interstellar',
#    'video': False,
#    'vote_average': 8.453,
#    'vote_count': 36933},
#   {'adult': False,
#    'backdrop_path': '/tDFvXn4tane9lUvFAFAUkMylwSr.jpg',
#    'genre_ids': [16, 18, 10752],
#    'id': 12477,
#    'original_language': 'ja',
#    'original_title': '火垂るの墓',
#    'overview': 'In the final months of World War II, 14-year-old Seita and his sister Setsuko are orphaned when their mother is killed during an air raid in Kobe, Japan. After a falling out with their aunt, they move into an abandoned bomb shelter. With no surviving relatives and their emergency rations depleted, Seita and Setsuko struggle to survive.',
#    'popularity': 0.0143,
#    'poster_path': '/k9tv1rXZbOhH7eiCk378x61kNQ1.jpg',
#    'release_date': '1988-04-16',
#    'title': 'Grave of the Fireflies',
#    'video': False,
#    'vote_average': 8.451,
#    'vote_count': 5842},
#   {'adult': False,
#    'backdrop_path': '/gavyCu1UaTaTNPsVaGXT6pe5u24.jpg',
#    'genre_ids': [35, 18],
#    'id': 637,
#    'original_language': 'it',
#    'original_title': 'La vita è bella',
#    'overview': 'A touching story of an Italian book seller of Jewish ancestry who lives in his own little fairy tale. His creative and happy life would come to an abrupt halt when his entire family is deported to a concentration camp during World War II. While locked up he tries to convince his son that the whole thing is just a game.',
#    'popularity': 12.26,
#    'poster_path': '/74hLDKjD5aGYOotO6esUVaeISa2.jpg',
#    'release_date': '1997-12-20',
#    'title': 'Life Is Beautiful',
#    'video': False,
#    'vote_average': 8.448,
#    'vote_count': 13302}],
#  'total_pages': 505,
#  'total_results': 10084}
